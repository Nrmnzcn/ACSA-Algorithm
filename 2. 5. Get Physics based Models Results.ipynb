# %%
# fundamental libraries
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# utils
from utils.save_result import *
from utils.visualization import *
from utils.test_functions import *
from utils.engineering_problem import *
from utils.ourmodel import *

# %%
physics_model_names = ["OriginalASO", "OriginalCDO", "OriginalEFO", "OriginalEO", "OriginalHGSO", "OriginalMVO", 
                     "OriginalNRO", "OriginalSA", "OriginalWDO", "Model"]

# %% [markdown]
# ### CLASSICAL TEST FUNCTION

# %%
f_names = ["F1", "F2", "F3", "F4", "F5", "F6", "F7", "F8", "F9", "F10", "F11", "F12", "F13", "F14", "F15", "F16"]

f_function = ["Ackley2", "Brent", "ChungReynolds", "Cigar", "Matyas", "Leon", "Michalewicz", "CrossInTray", 
                   "Hosaki", "Langermann", "Levy5", "Mishra5", "Alpine2","Hansen", "Himmelblau", "Chichinadze"]

# %% [markdown]
# #### Get Statistical Results

# %%
best_fit_statistic(test_folder="physics/classic", test_names=f_names, models=physics_model_names)
# Out:
#                         ASO       CDO       EFO        EO      HGSO       MVO  \
# Problem Statictic
# F1      min        0.056771  0.000000  0.151827  0.000000  0.646088  0.003206
#         std        0.168158  0.000000  0.797208  0.000000  0.186484  0.003897
# F10     min        0.664676  0.009436  0.699422  0.000000  0.023420  0.000403
#         std        0.075561  0.056770  0.834037  0.000000  0.203087  0.394670
# F11     min        0.088631  1.000000  0.107546  0.000000  0.050176  0.000024
#         std        0.405175  0.865398  1.000000  0.206376  0.795682  0.787871
# F12     min        0.024809  1.000000  0.169106  0.000000  0.569576  0.000000
#         std        0.015726  1.000000  0.401616  0.000000  0.206835  0.000000
# F13     min        0.050647  0.102770  0.449528  0.000000  1.000000  0.000232
#         std        0.017936  0.030307  0.684947  0.000000  0.143175  0.000071
# F14     min        0.151366  0.142131  1.000000  0.000000  0.319908  0.000003
# ...

# %% [markdown]
# #### Compare Models by Ranking

# %%
best_fitness(test_folder="physics/classic", test_names=f_names, models=physics_model_names)

# %%
compute_rank(test_folder="physics/classic", test_names=f_names)
# Out:
#    Problem   ASO   CDO   EFO    EO  HGSO   MVO   NRO     SA   WDO  Model
# 0       F1  7.00  1.00  8.64  1.00  8.36  6.00  1.00  10.00  5.00   1.00
# 1       F2  5.44  9.04  7.04  1.00  3.80  1.00  1.36   8.44  9.48   1.00
# 2       F3  6.96  1.00  9.04  1.00  8.04  1.48  1.00   9.84  2.52   1.00
# 3       F4  7.00  1.00  9.92  1.00  8.88  5.12  1.00   8.20  5.88   1.00
# 4       F5  6.76  1.00  9.76  1.00  8.16  3.24  1.00   9.08  1.00   2.64
# 5       F6  4.88  6.04  9.96  1.04  8.12  2.28  1.08   8.80  7.08   3.88
# 6       F7  5.28  5.80  8.12  1.00  9.00  3.76  1.00   9.76  7.04   2.52
# 7       F8  6.16  4.84  9.00  1.00  8.20  2.44  1.00   9.68  6.96   1.92
# 8       F9  5.24  5.92  9.56  1.00  8.32  3.68  1.00   9.08  6.88   2.60
# 9      F10  6.32  4.96  9.68  1.00  7.92  4.04  1.00   8.96  7.04   3.00
# 10     F11  4.80  9.68  8.84  1.08  6.72  4.36  1.92   7.00  7.60   2.96
# 11     F12  5.00  9.92  6.88  1.00  6.52  1.52  4.00   8.96  7.72   1.56
# ...

# %% [markdown]
# #### Compare Models by Signed Test

# %%
classic = signed_test(test_folder="physics/classic", test_names=f_names, trial_size=25)
classic
# Out:
#   Model2  (+)  (-)  Trials
# 0    ASO   13  387     400
# 1    CDO   20  380     400
# 2    EFO    0  400     400
# 3     EO  240  160     400
# 4   HGSO    3  397     400
# 5    MVO  131  269     400
# 6    NRO  197  203     400
# 7     SA    2  398     400
# 8    WDO   13  387     400

# %% [markdown]
# ### CEC22 FUNCTION

# %%
c_names = ["C1", "C2", "C3", "C4", "C5", "C6", "C7", "C8", "C9", "C10", "C11", "C12"]
c_function = ["F12022", "F22022", "F32022", "F42022", "F52022", "F62022", "F72022", 
              "F82022", "F92022", "F102022", "F112022", "F122022"]

# %% [markdown]
# #### Get Statistical Results

# %%
best_fit_statistic(test_folder="physics/cec22", test_names=c_names, models=physics_model_names)
# Out:
#                         ASO       CDO       EFO        EO      HGSO       MVO  \
# Problem Statictic
# C1      min        0.266819  0.709411  0.991516  0.000000  0.699949  0.000022
#         std        0.135359  0.135735  0.784146  0.000053  0.271974  0.000000
# C10     min        0.588184  0.892740  1.000000  0.000000  0.729130  0.043292
#         std        0.284977  0.000000  0.297466  0.918976  0.017427  1.000000
# C11     min        0.674713  0.785097  1.000000  0.448894  0.909658  0.000000
#         std        0.228938  0.126252  0.297434  0.248732  0.000000  1.000000
# C12     min        0.548307  1.000000  0.686074  0.541395  0.738172  0.565805
#         std        0.148798  0.640366  0.293279  0.000000  0.372279  0.122240
# C2      min        0.153364  0.574275  0.145641  0.000346  0.424892  0.000000
#         std        0.066177  0.024346  0.178869  0.015363  0.344874  0.018169
# C3      min        0.298712  0.521224  0.533701  0.000000  0.623036  0.000033
# ...

# %% [markdown]
# #### Compare Models by Ranking

# %%
best_fitness(test_folder="physics/cec22", test_names=c_names, models=physics_model_names)

# %%
compute_rank(test_folder="physics/cec22", test_names=c_names)
# Out:
#    Problem   ASO   CDO   EFO    EO  HGSO   MVO   NRO     SA   WDO  Model
# 0       C1  5.00  7.36  9.08  1.32  6.64  1.68  4.00   9.76  7.16   3.00
# 1       C2  5.04  6.88  6.16  2.16  7.92  2.08  3.44   9.08  9.92   2.32
# 2       C3  5.00  6.60  6.44  1.00  7.96  2.00  4.00   9.92  9.08   3.00
# 3       C4  5.76  4.96  7.68  1.00  7.32  4.16  3.12  10.00  9.00   2.00
# 4       C5  4.88  6.64  6.64  1.00  8.00  3.32  2.32  10.00  8.72   3.48
# 5       C6  5.00  9.88  6.20  2.52  6.80  3.08  1.44   9.08  8.04   2.96
# 6       C7  5.00  9.92  6.32  1.12  6.68  1.88  3.32   8.92  8.16   3.68
# 7       C8  5.88  5.00  8.80  1.12  7.44  2.00  2.88   9.76  8.00   4.12
# 8       C9  5.00  8.32  6.20  2.80  6.84  2.80  1.48   9.92  8.72   2.92
# 9      C10  3.84  6.76  9.08  4.24  6.56  3.00  2.52   8.92  8.68   1.40
# 10     C11  3.68  6.96  9.92  4.24  6.08  3.92  1.96   8.72  8.24   1.28
# 11     C12  4.96  9.16  6.04  1.24  7.08  2.52  4.00   8.80  8.76   2.44

# %% [markdown]
# #### Compare Models by Signed Test

# %%
cec22 = signed_test(test_folder="physics/cec22", test_names=c_names, trial_size=25)
cec22
# Out:
#   Model2  (+)  (-)  Trials
# 0    ASO   20  280     300
# 1    CDO   19  281     300
# 2    EFO    0  300     300
# 3     EO  203   97     300
# 4   HGSO    1  299     300
# 5    MVO  181  119     300
# 6    NRO  134  166     300
# 7     SA    1  299     300
# 8    WDO    2  298     300

# %% [markdown]
# ### RESULTS OF ALL TESTS

# %% [markdown]
# The comparison of the ACSA model and other methods is as follows. (-) indicates how many of the results have the minimum value, that is, the WINNING score.

# %%
all = classic + cec22 
all
# Out:
#      Model2  (+)  (-)  Trials
# 0    ASOASO   33  667     700
# 1    CDOCDO   39  661     700
# 2    EFOEFO    0  700     700
# 3      EOEO  443  257     700
# 4  HGSOHGSO    4  696     700
# 5    MVOMVO  312  388     700
# 6    NRONRO  331  369     700
# 7      SASA    3  697     700
# 8    WDOWDO   15  685     700

# %%
classic.to_csv('results/physics_classic.csv', index=False)
cec22.to_csv('results/physics_cec.csv', index=False)
all.to_csv('results/physics_total.csv', index=False)
