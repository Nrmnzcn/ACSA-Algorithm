# %%
# fundamental libraries
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# utils
from utils.save_result import *
from utils.visualization import *
from utils.test_functions import *
from utils.engineering_problem import *
from utils.ourmodel import *

# %%
human_model_names = ["OriginalBSO", "OriginalCA", "OriginalCHIO", "OriginalFBIO", "OriginalLCO", 
                     "OriginalSARO", "OriginalSPBO", "OriginalSSDO", "OriginalTLO", "Model"]

# %% [markdown]
# ### CLASSICAL TEST FUNCTION

# %%
f_names = ["F1", "F2", "F3", "F4", "F5", "F6", "F7", "F8", "F9", "F10", "F11", "F12", "F13", "F14", "F15", "F16"]

f_function = ["Ackley2", "Brent", "ChungReynolds", "Cigar", "Matyas", "Leon", "Michalewicz", "CrossInTray", 
                   "Hosaki", "Langermann", "Levy5", "Mishra5", "Alpine2","Hansen", "Himmelblau", "Chichinadze"]

# %% [markdown]
# #### Get Statistical Results

# %%
best_fit_statistic(test_folder="human/classic", test_names=f_names, models=human_model_names)
# Out:
#                         BSO        CA      CHIO      FBIO       LCO     Model  \
# Problem Statictic
# F1      min        0.013369  0.000000  1.000000  0.000000  0.000000  0.000000
#         std        0.004755  0.113087  1.000000  0.000000  0.000000  0.000000
# F10     min        0.001636  0.000000  1.000000  0.000000  0.000000  0.000063
#         std        0.001022  1.000000  0.173671  0.000000  0.988231  0.017044
# F11     min        0.000925  0.000000  1.000000  0.000000  0.000000  0.000051
#         std        0.122495  1.000000  0.852345  0.000000  0.857696  0.001180
# F12     min        0.008881  1.000000  0.000028  0.000000  0.000000  0.000000
#         std        0.032637  1.000000  0.195242  0.000000  0.000000  0.000004
# F13     min        0.000273  0.000000  0.059676  0.000000  0.000000  0.000003
#         std        0.000452  0.086727  0.109574  0.000000  0.000000  0.000064
# F14     min        0.013335  0.000000  1.000000  0.000002  0.000000  0.012862
# ...

# %% [markdown]
# #### Compare Models by Ranking

# %%
best_fitness(test_folder="human/classic", test_names=f_names, models=human_model_names)

# %%
compute_rank(test_folder="human/classic", test_names=f_names)
# Out:
#    Problem   BSO     CA   CHIO  FBIO   LCO  SARO  SPBO   SSDO   TLO  Model
# 0       F1  8.72   2.56  10.00  1.00  1.00  1.00  1.00   8.16  1.00   1.00
# 1       F2  9.00  10.00   1.00  1.00  1.00  1.00  1.00   1.00  1.00   1.00
# 2       F3  1.00   1.96  10.00  1.00  1.00  1.00  1.00   1.84  1.00   1.00
# 3       F4  9.00   1.24  10.00  1.00  1.00  1.00  1.00   8.00  1.00   1.00
# 4       F5  8.36   1.00  10.00  1.00  1.00  1.00  1.00   1.48  1.00   3.80
# 5       F6  6.92   8.60   8.56  1.00  1.00  1.00  1.00   9.56  4.68   5.64
# 6       F7  7.80   2.88   9.00  1.00  1.00  1.00  1.00  10.00  1.00   5.28
# 7       F8  7.24   4.60  10.00  1.00  1.00  1.00  1.00   9.00  1.00   3.20
# 8       F9  7.96   1.48   9.00  1.00  1.00  1.00  1.00  10.00  1.00   5.76
# 9      F10  7.24   6.48   8.56  1.00  1.64  1.00  1.00   9.48  1.00   6.04
# 10     F11  7.04   5.64  10.00  1.04  3.48  1.00  1.52   8.28  3.28   6.00
# ...

# %% [markdown]
# #### Compare Models by Signed Test

# %%
classic = signed_test(test_folder="human/classic", test_names=f_names, trial_size=25)
classic
# Out:
#   Model2  (+)  (-)  Trials
# 0    BSO   33  367     400
# 1     CA  116  284     400
# 2   CHIO    1  399     400
# 3   FBIO  241  159     400
# 4    LCO  219  181     400
# 5   SARO  233  167     400
# 6   SPBO  227  173     400
# 7   SSDO   14  386     400
# 8    TLO  218  182     400

# %% [markdown]
# ### CEC22 FUNCTION

# %%
c_names = ["C1", "C2", "C3", "C4", "C5", "C6", "C7", "C8", "C9", "C10", "C11", "C12"]
c_function = ["F12022", "F22022", "F32022", "F42022", "F52022", "F62022", "F72022", 
              "F82022", "F92022", "F102022", "F112022", "F122022"]

# %% [markdown]
# #### Get Statistical Results

# %%
best_fit_statistic(test_folder="human/cec22", test_names=c_names, models=human_model_names)
# Out:
#                         BSO        CA      CHIO      FBIO       LCO     Model  \
# Problem Statictic
# C1      min        0.199689  0.008694  1.000000  0.000000  0.057207  0.000251
#         std        0.462727  0.540701  1.000000  0.000000  0.304844  0.001119
# C10     min        0.311428  1.000000  0.549310  0.184863  0.288548  0.048289
#         std        0.784713  0.000000  0.488387  0.646134  0.823413  1.000000
# C11     min        0.000000  1.000000  0.934991  0.481914  0.322458  0.094921
#         std        0.821331  0.000000  0.137316  0.506249  0.670796  1.000000
# C12     min        0.792083  0.996288  0.528846  0.489406  0.737460  0.000000
#         std        1.000000  0.274092  0.572803  0.228107  0.682770  0.629172
# C2      min        0.407670  0.070065  0.348903  0.000000  0.031106  0.003420
#         std        1.000000  0.067508  0.616632  0.037745  0.179789  0.052635
# C3      min        0.193196  0.002268  0.775382  0.000000  0.032249  0.000114
# ...

# %% [markdown]
# #### Compare Models by Ranking

# %%
best_fitness(test_folder="human/cec22", test_names=c_names, models=human_model_names)

# %%
compute_rank(test_folder="human/cec22", test_names=c_names)
# Out:
#    Problem   BSO    CA   CHIO  FBIO   LCO  SARO  SPBO   SSDO   TLO  Model
# 0       C1  7.88  5.80  10.00  1.00  5.32  3.88  7.04   8.96  2.00   3.12
# 1       C2  8.24  5.32   9.00  1.32  5.72  2.80  6.96   9.76  1.88   4.00
# 2       C3  7.96  5.00   9.56  1.00  6.00  3.00  7.04   9.44  1.52   4.00
# 3       C4  8.48  5.36  10.00  1.00  2.48  4.60  4.04   8.48  6.08   4.48
# 4       C5  7.72  3.96  10.00  2.80  6.16  2.28  7.00   8.96  1.00   5.12
# 5       C6  5.28  3.20   9.00  1.92  6.48  1.12  6.56  10.00  4.40   7.04
# 6       C7  8.00  4.28   9.00  1.08  4.28  3.52  5.20  10.00  2.84   6.80
# 7       C8  7.84  4.00   9.16  1.08  4.96  1.92  6.04   9.84  3.04   7.12
# 8       C9  8.68  4.84   8.40  1.56  5.84  2.36  6.96   9.92  2.08   4.36
# 9      C10  6.84  9.52   5.36  2.00  7.56  5.36  1.76   8.84  5.32   2.44
# 10     C11  6.20  9.92   5.24  1.88  6.68  6.28  2.88   8.76  5.44   1.72
# 11     C12  9.24  7.28   7.20  2.56  5.84  2.88  5.48   9.52  1.56   3.44

# %% [markdown]
# #### Compare Models by Signed Test

# %%
cec22 = signed_test(test_folder="human/cec22", test_names=c_names, trial_size=25)
cec22
# Out:
#   Model2  (+)  (-)  Trials
# 0    BSO   49  251     300
# 1     CA  102  198     300
# 2   CHIO   12  288     300
# 3   FBIO  250   50     300
# 4    LCO  105  195     300
# 5   SARO  206   94     300
# 6   SPBO  102  198     300
# 7   SSDO   10  290     300
# 8    TLO  222   78     300

# %% [markdown]
# ### RESULTS OF ALL TESTS

# %% [markdown]
# The comparison of the ACSA model and other methods is as follows. (-) indicates how many of the results have the minimum value, that is, the WINNING score.

# %%
all = classic + cec22 
all
# Out:
#      Model2  (+)  (-)  Trials
# 0    BSOBSO   82  618     700
# 1      CACA  218  482     700
# 2  CHIOCHIO   13  687     700
# 3  FBIOFBIO  491  209     700
# 4    LCOLCO  324  376     700
# 5  SAROSARO  439  261     700
# 6  SPBOSPBO  329  371     700
# 7  SSDOSSDO   24  676     700
# 8    TLOTLO  440  260     700

# %%
classic.to_csv('results/human_classic.csv', index=False)
cec22.to_csv('results/human_cec.csv', index=False)
all.to_csv('results/human_total.csv', index=False)
