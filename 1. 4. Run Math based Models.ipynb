# %%
# fundamental libraries
import numpy as np
import pandas as pd

# utils
from utils.save_result import *
from utils.visualization import *
from utils.multitask import *
from utils.test_functions import *
from utils.engineering_problem import *
from utils.ourmodel import *
from utils.optimizers import *

# %% [markdown]
# ## Define Test Functions

# %%
Fnames, Ffunctions, Fproblems, Flatexs = classical_test_function()
Cnames, Cfunctions, Cproblems, Clatexs = cec22_test_function_with_bias(dimension=10)

# %%
Ffunctions
# Out:
# [<opfunu.name_based.a_func.Ackley02 at 0x1a1d01c3e00>,
#  <opfunu.name_based.b_func.Brent at 0x1a1d0437a10>,
#  <opfunu.name_based.c_func.ChungReynolds at 0x1a1b5ac2fc0>,
#  <opfunu.name_based.c_func.Cigar at 0x1a1d0658b30>,
#  <opfunu.name_based.m_func.Matyas at 0x1a1cfec2b40>,
#  <opfunu.name_based.l_func.Leon at 0x1a1d00443b0>,
#  <opfunu.name_based.m_func.Michalewicz at 0x1a1cfff4ef0>,
#  <opfunu.name_based.c_func.CrossInTray at 0x1a1cfff4530>,
#  <opfunu.name_based.h_func.Hosaki at 0x1a19f1b8530>,
#  <opfunu.name_based.l_func.Langermann at 0x1a1cff0f710>,
#  <opfunu.name_based.l_func.Levy05 at 0x1a1d0526600>,
#  <opfunu.name_based.m_func.Mishra05 at 0x1a19f1b84d0>,
#  <opfunu.name_based.a_func.Alpine02 at 0x1a1cfdbe480>,
#  <opfunu.name_based.h_func.Hansen at 0x1a1cfec2b70>,
#  <opfunu.name_based.h_func.Himmelblau at 0x1a19f1b8500>,
#  <opfunu.name_based.c_func.Chichinadze at 0x1a19f1b8650>]

# %% [markdown]
# ## Define Models

# %% [markdown]
# * Arithmetic Optimization Algorithm (AOA)
# * Chaos Game Optimization (CGO)
# * Hill Climbing (HC)
# * Sine Cosine Algorithm (SCA)
# * Tabu Search (TS)

# %%
aoa, cgo, hc, sca, ts = math_based()
list_models = [aoa, cgo, hc, sca, ts]

# %%
eh = 0.6
en = 1.8
sh = 0.3
sn = 0.002
nh_rate=0.2
scale=0.1

epoch = 200
pop_size = 100

acsa = Model(epoch, pop_size, eh, en, sh, sn, nh_rate, scale)

# %% [markdown]
# ## Run Multitask

# %% [markdown]
# #### CLASSICAL TEST FUNCTION

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=list_models, problems=Fproblems)
    multitask.execute(n_trials=25, save_path="history/math/classic", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Ackley2 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Brent using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: ChungReynolds using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Cigar using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Matyas using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Leon using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Michalewicz using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: CrossInTray using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Hosaki using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Langermann using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Levy5 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Mishra5 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Alpine2 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Hansen using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Himmelblau using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: Chichinadze using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: Ackley2 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: Brent using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: ChungReynolds using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: Cigar using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: Matyas using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: Leon using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: Michalewicz using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: CrossInTray using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: Hosaki using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: Langermann using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: Levy5 using algorithm: OriginalCGO, on the: 13 trial
# ...
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 3 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 4 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 5 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 6 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 7 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 8 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 9 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 10 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 11 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 12 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 13 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 14 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 15 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 16 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 17 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 18 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 19 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 20 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 21 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 22 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 23 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 24 trial
# Solving problem: CrossInTray using algorithm: OriginalTS, on the: 25 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 1 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 2 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 3 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 4 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 5 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 6 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 7 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 8 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 9 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 10 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 11 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 12 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 13 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 14 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 15 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 16 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 17 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 18 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 19 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 20 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 21 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 22 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 23 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 24 trial
# Solving problem: Hosaki using algorithm: OriginalTS, on the: 25 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 1 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 2 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 3 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 4 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 5 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 6 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 7 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 8 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 9 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 10 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 11 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 12 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 13 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 14 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 15 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 16 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 17 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 18 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 19 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 20 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 21 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 22 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 23 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 24 trial
# Solving problem: Langermann using algorithm: OriginalTS, on the: 25 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: Levy5 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: Mishra5 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: Alpine2 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 1 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 2 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 3 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 4 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 5 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 6 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 7 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 8 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 9 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 10 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 11 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 12 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 13 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 14 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 15 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 16 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 17 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 18 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 19 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 20 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 21 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 22 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 23 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 24 trial
# Solving problem: Hansen using algorithm: OriginalTS, on the: 25 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 1 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 2 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 3 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 4 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 5 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 6 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 7 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 8 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 9 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 10 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 11 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 12 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 13 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 14 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 15 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 16 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 17 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 18 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 19 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 20 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 21 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 22 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 23 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 24 trial
# Solving problem: Himmelblau using algorithm: OriginalTS, on the: 25 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 1 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 2 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 3 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 4 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 5 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 6 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 7 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 8 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 9 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 10 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 11 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 12 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 13 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 14 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 15 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 16 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 17 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 18 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 19 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 20 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 21 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 22 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 23 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 24 trial
# Solving problem: Chichinadze using algorithm: OriginalTS, on the: 25 trial

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=[acsa], problems=Fproblems)
    multitask.execute(n_trials=25, save_path="history/math/classic", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: Ackley2 using algorithm: Model, on the: 1 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 2 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 3 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 4 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 5 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 6 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 7 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 8 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 9 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 10 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 11 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 12 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 13 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 14 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 15 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 16 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 17 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 18 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 19 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 20 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 21 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 22 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 23 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 24 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 25 trial
# Solving problem: Brent using algorithm: Model, on the: 1 trial
# Solving problem: Brent using algorithm: Model, on the: 2 trial
# Solving problem: Brent using algorithm: Model, on the: 3 trial
# Solving problem: Brent using algorithm: Model, on the: 4 trial
# Solving problem: Brent using algorithm: Model, on the: 5 trial
# Solving problem: Brent using algorithm: Model, on the: 6 trial
# Solving problem: Brent using algorithm: Model, on the: 7 trial
# Solving problem: Brent using algorithm: Model, on the: 8 trial
# Solving problem: Brent using algorithm: Model, on the: 9 trial
# Solving problem: Brent using algorithm: Model, on the: 10 trial
# Solving problem: Brent using algorithm: Model, on the: 11 trial
# Solving problem: Brent using algorithm: Model, on the: 12 trial
# Solving problem: Brent using algorithm: Model, on the: 13 trial
# Solving problem: Brent using algorithm: Model, on the: 14 trial
# Solving problem: Brent using algorithm: Model, on the: 15 trial
# Solving problem: Brent using algorithm: Model, on the: 16 trial
# Solving problem: Brent using algorithm: Model, on the: 17 trial
# Solving problem: Brent using algorithm: Model, on the: 18 trial
# Solving problem: Brent using algorithm: Model, on the: 19 trial
# Solving problem: Brent using algorithm: Model, on the: 20 trial
# Solving problem: Brent using algorithm: Model, on the: 21 trial
# Solving problem: Brent using algorithm: Model, on the: 22 trial
# Solving problem: Brent using algorithm: Model, on the: 23 trial
# Solving problem: Brent using algorithm: Model, on the: 24 trial
# Solving problem: Brent using algorithm: Model, on the: 25 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 1 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 2 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 3 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 4 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 5 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 6 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 7 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 8 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 9 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 10 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 11 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 12 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 13 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 14 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 15 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 16 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 17 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 18 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 19 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 20 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 21 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 22 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 23 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 24 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 25 trial
# Solving problem: Cigar using algorithm: Model, on the: 1 trial
# Solving problem: Cigar using algorithm: Model, on the: 2 trial
# Solving problem: Cigar using algorithm: Model, on the: 3 trial
# Solving problem: Cigar using algorithm: Model, on the: 4 trial
# Solving problem: Cigar using algorithm: Model, on the: 5 trial
# Solving problem: Cigar using algorithm: Model, on the: 6 trial
# Solving problem: Cigar using algorithm: Model, on the: 7 trial
# Solving problem: Cigar using algorithm: Model, on the: 8 trial
# Solving problem: Cigar using algorithm: Model, on the: 9 trial
# Solving problem: Cigar using algorithm: Model, on the: 10 trial
# Solving problem: Cigar using algorithm: Model, on the: 11 trial
# Solving problem: Cigar using algorithm: Model, on the: 12 trial
# Solving problem: Cigar using algorithm: Model, on the: 13 trial
# Solving problem: Cigar using algorithm: Model, on the: 14 trial
# Solving problem: Cigar using algorithm: Model, on the: 15 trial
# Solving problem: Cigar using algorithm: Model, on the: 16 trial
# Solving problem: Cigar using algorithm: Model, on the: 17 trial
# Solving problem: Cigar using algorithm: Model, on the: 18 trial
# Solving problem: Cigar using algorithm: Model, on the: 19 trial
# Solving problem: Cigar using algorithm: Model, on the: 20 trial
# Solving problem: Cigar using algorithm: Model, on the: 21 trial
# Solving problem: Cigar using algorithm: Model, on the: 22 trial
# Solving problem: Cigar using algorithm: Model, on the: 23 trial
# Solving problem: Cigar using algorithm: Model, on the: 24 trial
# Solving problem: Cigar using algorithm: Model, on the: 25 trial
# Solving problem: Matyas using algorithm: Model, on the: 1 trial
# Solving problem: Matyas using algorithm: Model, on the: 2 trial
# Solving problem: Matyas using algorithm: Model, on the: 3 trial
# Solving problem: Matyas using algorithm: Model, on the: 4 trial
# Solving problem: Matyas using algorithm: Model, on the: 5 trial
# Solving problem: Matyas using algorithm: Model, on the: 6 trial
# Solving problem: Matyas using algorithm: Model, on the: 7 trial
# Solving problem: Matyas using algorithm: Model, on the: 8 trial
# Solving problem: Matyas using algorithm: Model, on the: 9 trial
# Solving problem: Matyas using algorithm: Model, on the: 10 trial
# Solving problem: Matyas using algorithm: Model, on the: 11 trial
# Solving problem: Matyas using algorithm: Model, on the: 12 trial
# Solving problem: Matyas using algorithm: Model, on the: 13 trial
# Solving problem: Matyas using algorithm: Model, on the: 14 trial
# Solving problem: Matyas using algorithm: Model, on the: 15 trial
# Solving problem: Matyas using algorithm: Model, on the: 16 trial
# Solving problem: Matyas using algorithm: Model, on the: 17 trial
# Solving problem: Matyas using algorithm: Model, on the: 18 trial
# Solving problem: Matyas using algorithm: Model, on the: 19 trial
# Solving problem: Matyas using algorithm: Model, on the: 20 trial
# Solving problem: Matyas using algorithm: Model, on the: 21 trial
# Solving problem: Matyas using algorithm: Model, on the: 22 trial
# Solving problem: Matyas using algorithm: Model, on the: 23 trial
# Solving problem: Matyas using algorithm: Model, on the: 24 trial
# Solving problem: Matyas using algorithm: Model, on the: 25 trial
# Solving problem: Leon using algorithm: Model, on the: 1 trial
# Solving problem: Leon using algorithm: Model, on the: 2 trial
# Solving problem: Leon using algorithm: Model, on the: 3 trial
# Solving problem: Leon using algorithm: Model, on the: 4 trial
# Solving problem: Leon using algorithm: Model, on the: 5 trial
# Solving problem: Leon using algorithm: Model, on the: 6 trial
# Solving problem: Leon using algorithm: Model, on the: 7 trial
# Solving problem: Leon using algorithm: Model, on the: 8 trial
# Solving problem: Leon using algorithm: Model, on the: 9 trial
# Solving problem: Leon using algorithm: Model, on the: 10 trial
# Solving problem: Leon using algorithm: Model, on the: 11 trial
# Solving problem: Leon using algorithm: Model, on the: 12 trial
# Solving problem: Leon using algorithm: Model, on the: 13 trial
# Solving problem: Leon using algorithm: Model, on the: 14 trial
# Solving problem: Leon using algorithm: Model, on the: 15 trial
# Solving problem: Leon using algorithm: Model, on the: 16 trial
# Solving problem: Leon using algorithm: Model, on the: 17 trial
# Solving problem: Leon using algorithm: Model, on the: 18 trial
# Solving problem: Leon using algorithm: Model, on the: 19 trial
# Solving problem: Leon using algorithm: Model, on the: 20 trial
# Solving problem: Leon using algorithm: Model, on the: 21 trial
# Solving problem: Leon using algorithm: Model, on the: 22 trial
# Solving problem: Leon using algorithm: Model, on the: 23 trial
# Solving problem: Leon using algorithm: Model, on the: 24 trial
# Solving problem: Leon using algorithm: Model, on the: 25 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 1 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 2 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 3 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 4 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 5 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 6 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 7 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 8 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 9 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 10 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 11 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 12 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 13 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 14 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 15 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 16 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 17 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 18 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 19 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 20 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 21 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 22 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 23 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 24 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 25 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 1 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 2 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 3 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 4 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 5 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 6 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 7 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 8 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 9 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 10 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 11 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 12 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 13 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 14 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 15 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 16 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 17 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 18 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 19 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 20 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 21 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 22 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 23 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 24 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 25 trial
# Solving problem: Hosaki using algorithm: Model, on the: 1 trial
# Solving problem: Hosaki using algorithm: Model, on the: 2 trial
# Solving problem: Hosaki using algorithm: Model, on the: 3 trial
# Solving problem: Hosaki using algorithm: Model, on the: 4 trial
# Solving problem: Hosaki using algorithm: Model, on the: 5 trial
# Solving problem: Hosaki using algorithm: Model, on the: 6 trial
# Solving problem: Hosaki using algorithm: Model, on the: 7 trial
# Solving problem: Hosaki using algorithm: Model, on the: 8 trial
# Solving problem: Hosaki using algorithm: Model, on the: 9 trial
# Solving problem: Hosaki using algorithm: Model, on the: 10 trial
# Solving problem: Hosaki using algorithm: Model, on the: 11 trial
# Solving problem: Hosaki using algorithm: Model, on the: 12 trial
# Solving problem: Hosaki using algorithm: Model, on the: 13 trial
# Solving problem: Hosaki using algorithm: Model, on the: 14 trial
# Solving problem: Hosaki using algorithm: Model, on the: 15 trial
# Solving problem: Hosaki using algorithm: Model, on the: 16 trial
# Solving problem: Hosaki using algorithm: Model, on the: 17 trial
# Solving problem: Hosaki using algorithm: Model, on the: 18 trial
# Solving problem: Hosaki using algorithm: Model, on the: 19 trial
# Solving problem: Hosaki using algorithm: Model, on the: 20 trial
# Solving problem: Hosaki using algorithm: Model, on the: 21 trial
# Solving problem: Hosaki using algorithm: Model, on the: 22 trial
# Solving problem: Hosaki using algorithm: Model, on the: 23 trial
# Solving problem: Hosaki using algorithm: Model, on the: 24 trial
# Solving problem: Hosaki using algorithm: Model, on the: 25 trial
# Solving problem: Langermann using algorithm: Model, on the: 1 trial
# Solving problem: Langermann using algorithm: Model, on the: 2 trial
# Solving problem: Langermann using algorithm: Model, on the: 3 trial
# Solving problem: Langermann using algorithm: Model, on the: 4 trial
# Solving problem: Langermann using algorithm: Model, on the: 5 trial
# Solving problem: Langermann using algorithm: Model, on the: 6 trial
# Solving problem: Langermann using algorithm: Model, on the: 7 trial
# Solving problem: Langermann using algorithm: Model, on the: 8 trial
# Solving problem: Langermann using algorithm: Model, on the: 9 trial
# Solving problem: Langermann using algorithm: Model, on the: 10 trial
# Solving problem: Langermann using algorithm: Model, on the: 11 trial
# Solving problem: Langermann using algorithm: Model, on the: 12 trial
# Solving problem: Langermann using algorithm: Model, on the: 13 trial
# Solving problem: Langermann using algorithm: Model, on the: 14 trial
# Solving problem: Langermann using algorithm: Model, on the: 15 trial
# Solving problem: Langermann using algorithm: Model, on the: 16 trial
# Solving problem: Langermann using algorithm: Model, on the: 17 trial
# Solving problem: Langermann using algorithm: Model, on the: 18 trial
# Solving problem: Langermann using algorithm: Model, on the: 19 trial
# Solving problem: Langermann using algorithm: Model, on the: 20 trial
# Solving problem: Langermann using algorithm: Model, on the: 21 trial
# Solving problem: Langermann using algorithm: Model, on the: 22 trial
# Solving problem: Langermann using algorithm: Model, on the: 23 trial
# Solving problem: Langermann using algorithm: Model, on the: 24 trial
# Solving problem: Langermann using algorithm: Model, on the: 25 trial
# Solving problem: Levy5 using algorithm: Model, on the: 1 trial
# Solving problem: Levy5 using algorithm: Model, on the: 2 trial
# Solving problem: Levy5 using algorithm: Model, on the: 3 trial
# Solving problem: Levy5 using algorithm: Model, on the: 4 trial
# Solving problem: Levy5 using algorithm: Model, on the: 5 trial
# Solving problem: Levy5 using algorithm: Model, on the: 6 trial
# Solving problem: Levy5 using algorithm: Model, on the: 7 trial
# Solving problem: Levy5 using algorithm: Model, on the: 8 trial
# Solving problem: Levy5 using algorithm: Model, on the: 9 trial
# Solving problem: Levy5 using algorithm: Model, on the: 10 trial
# Solving problem: Levy5 using algorithm: Model, on the: 11 trial
# Solving problem: Levy5 using algorithm: Model, on the: 12 trial
# Solving problem: Levy5 using algorithm: Model, on the: 13 trial
# Solving problem: Levy5 using algorithm: Model, on the: 14 trial
# Solving problem: Levy5 using algorithm: Model, on the: 15 trial
# Solving problem: Levy5 using algorithm: Model, on the: 16 trial
# Solving problem: Levy5 using algorithm: Model, on the: 17 trial
# Solving problem: Levy5 using algorithm: Model, on the: 18 trial
# Solving problem: Levy5 using algorithm: Model, on the: 19 trial
# Solving problem: Levy5 using algorithm: Model, on the: 20 trial
# Solving problem: Levy5 using algorithm: Model, on the: 21 trial
# Solving problem: Levy5 using algorithm: Model, on the: 22 trial
# Solving problem: Levy5 using algorithm: Model, on the: 23 trial
# Solving problem: Levy5 using algorithm: Model, on the: 24 trial
# Solving problem: Levy5 using algorithm: Model, on the: 25 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 1 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 2 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 3 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 4 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 5 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 6 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 7 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 8 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 9 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 10 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 11 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 12 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 13 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 14 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 15 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 16 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 17 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 18 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 19 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 20 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 21 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 22 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 23 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 24 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 25 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 1 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 2 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 3 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 4 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 5 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 6 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 7 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 8 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 9 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 10 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 11 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 12 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 13 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 14 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 15 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 16 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 17 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 18 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 19 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 20 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 21 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 22 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 23 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 24 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 25 trial
# Solving problem: Hansen using algorithm: Model, on the: 1 trial
# Solving problem: Hansen using algorithm: Model, on the: 2 trial
# Solving problem: Hansen using algorithm: Model, on the: 3 trial
# Solving problem: Hansen using algorithm: Model, on the: 4 trial
# Solving problem: Hansen using algorithm: Model, on the: 5 trial
# Solving problem: Hansen using algorithm: Model, on the: 6 trial
# Solving problem: Hansen using algorithm: Model, on the: 7 trial
# Solving problem: Hansen using algorithm: Model, on the: 8 trial
# Solving problem: Hansen using algorithm: Model, on the: 9 trial
# Solving problem: Hansen using algorithm: Model, on the: 10 trial
# Solving problem: Hansen using algorithm: Model, on the: 11 trial
# Solving problem: Hansen using algorithm: Model, on the: 12 trial
# Solving problem: Hansen using algorithm: Model, on the: 13 trial
# Solving problem: Hansen using algorithm: Model, on the: 14 trial
# Solving problem: Hansen using algorithm: Model, on the: 15 trial
# Solving problem: Hansen using algorithm: Model, on the: 16 trial
# Solving problem: Hansen using algorithm: Model, on the: 17 trial
# Solving problem: Hansen using algorithm: Model, on the: 18 trial
# Solving problem: Hansen using algorithm: Model, on the: 19 trial
# Solving problem: Hansen using algorithm: Model, on the: 20 trial
# Solving problem: Hansen using algorithm: Model, on the: 21 trial
# Solving problem: Hansen using algorithm: Model, on the: 22 trial
# Solving problem: Hansen using algorithm: Model, on the: 23 trial
# Solving problem: Hansen using algorithm: Model, on the: 24 trial
# Solving problem: Hansen using algorithm: Model, on the: 25 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 1 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 2 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 3 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 4 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 5 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 6 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 7 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 8 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 9 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 10 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 11 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 12 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 13 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 14 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 15 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 16 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 17 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 18 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 19 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 20 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 21 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 22 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 23 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 24 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 25 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 1 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 2 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 3 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 4 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 5 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 6 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 7 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 8 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 9 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 10 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 11 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 12 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 13 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 14 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 15 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 16 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 17 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 18 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 19 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 20 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 21 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 22 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 23 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 24 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 25 trial

# %% [markdown]
# #### CEC22 TEST FUNCTION

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=list_models, problems=Cproblems)
    multitask.execute(n_trials=25, save_path="history/math/cec22", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F12022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F22022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F32022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F42022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F52022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F62022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F72022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F82022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F92022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F102022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F112022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 1 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 2 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 3 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 4 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 5 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 6 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 7 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 8 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 9 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 10 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 11 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 12 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 13 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 14 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 15 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 16 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 17 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 18 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 19 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 20 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 21 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 22 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 23 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 24 trial
# Solving problem: F122022 using algorithm: OriginalAOA, on the: 25 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F12022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F22022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F32022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F42022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F52022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F62022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F72022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F82022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F92022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F102022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F112022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 1 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 2 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 3 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 4 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 5 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 6 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 7 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 8 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 9 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 10 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 11 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 12 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 13 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 14 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 15 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 16 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 17 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 18 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 19 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 20 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 21 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 22 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 23 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 24 trial
# Solving problem: F122022 using algorithm: OriginalCGO, on the: 25 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 1 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 2 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 3 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 4 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 5 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 6 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 7 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 8 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 9 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 10 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 11 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 12 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 13 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 14 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 15 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 16 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 17 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 18 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 19 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 20 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 21 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 22 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 23 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 24 trial
# Solving problem: F12022 using algorithm: OriginalHC, on the: 25 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 1 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 2 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 3 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 4 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 5 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 6 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 7 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 8 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 9 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 10 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 11 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 12 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 13 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 14 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 15 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 16 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 17 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 18 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 19 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 20 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 21 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 22 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 23 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 24 trial
# Solving problem: F22022 using algorithm: OriginalHC, on the: 25 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 1 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 2 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 3 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 4 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 5 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 6 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 7 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 8 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 9 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 10 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 11 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 12 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 13 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 14 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 15 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 16 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 17 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 18 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 19 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 20 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 21 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 22 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 23 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 24 trial
# Solving problem: F32022 using algorithm: OriginalHC, on the: 25 trial
# Solving problem: F42022 using algorithm: OriginalHC, on the: 1 trial
# Solving problem: F42022 using algorithm: OriginalHC, on the: 2 trial
# Solving problem: F42022 using algorithm: OriginalHC, on the: 3 trial
# ...
# Solving problem: F32022 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: F32022 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: F32022 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: F42022 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: F52022 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: F62022 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: F72022 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: F82022 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: F92022 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: F102022 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: F112022 using algorithm: OriginalTS, on the: 25 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 1 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 2 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 3 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 4 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 5 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 6 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 7 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 8 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 9 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 10 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 11 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 12 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 13 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 14 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 15 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 16 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 17 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 18 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 19 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 20 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 21 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 22 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 23 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 24 trial
# Solving problem: F122022 using algorithm: OriginalTS, on the: 25 trial

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=[acsa], problems=Cproblems)
    multitask.execute(n_trials=25, save_path="history/math/cec22", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: F12022 using algorithm: Model, on the: 1 trial
# Solving problem: F12022 using algorithm: Model, on the: 2 trial
# Solving problem: F12022 using algorithm: Model, on the: 3 trial
# Solving problem: F12022 using algorithm: Model, on the: 4 trial
# Solving problem: F12022 using algorithm: Model, on the: 5 trial
# Solving problem: F12022 using algorithm: Model, on the: 6 trial
# Solving problem: F12022 using algorithm: Model, on the: 7 trial
# Solving problem: F12022 using algorithm: Model, on the: 8 trial
# Solving problem: F12022 using algorithm: Model, on the: 9 trial
# Solving problem: F12022 using algorithm: Model, on the: 10 trial
# Solving problem: F12022 using algorithm: Model, on the: 11 trial
# Solving problem: F12022 using algorithm: Model, on the: 12 trial
# Solving problem: F12022 using algorithm: Model, on the: 13 trial
# Solving problem: F12022 using algorithm: Model, on the: 14 trial
# Solving problem: F12022 using algorithm: Model, on the: 15 trial
# Solving problem: F12022 using algorithm: Model, on the: 16 trial
# Solving problem: F12022 using algorithm: Model, on the: 17 trial
# Solving problem: F12022 using algorithm: Model, on the: 18 trial
# Solving problem: F12022 using algorithm: Model, on the: 19 trial
# Solving problem: F12022 using algorithm: Model, on the: 20 trial
# Solving problem: F12022 using algorithm: Model, on the: 21 trial
# Solving problem: F12022 using algorithm: Model, on the: 22 trial
# Solving problem: F12022 using algorithm: Model, on the: 23 trial
# Solving problem: F12022 using algorithm: Model, on the: 24 trial
# Solving problem: F12022 using algorithm: Model, on the: 25 trial
# Solving problem: F22022 using algorithm: Model, on the: 1 trial
# Solving problem: F22022 using algorithm: Model, on the: 2 trial
# Solving problem: F22022 using algorithm: Model, on the: 3 trial
# Solving problem: F22022 using algorithm: Model, on the: 4 trial
# Solving problem: F22022 using algorithm: Model, on the: 5 trial
# Solving problem: F22022 using algorithm: Model, on the: 6 trial
# Solving problem: F22022 using algorithm: Model, on the: 7 trial
# Solving problem: F22022 using algorithm: Model, on the: 8 trial
# Solving problem: F22022 using algorithm: Model, on the: 9 trial
# Solving problem: F22022 using algorithm: Model, on the: 10 trial
# Solving problem: F22022 using algorithm: Model, on the: 11 trial
# Solving problem: F22022 using algorithm: Model, on the: 12 trial
# Solving problem: F22022 using algorithm: Model, on the: 13 trial
# Solving problem: F22022 using algorithm: Model, on the: 14 trial
# Solving problem: F22022 using algorithm: Model, on the: 15 trial
# Solving problem: F22022 using algorithm: Model, on the: 16 trial
# Solving problem: F22022 using algorithm: Model, on the: 17 trial
# Solving problem: F22022 using algorithm: Model, on the: 18 trial
# Solving problem: F22022 using algorithm: Model, on the: 19 trial
# Solving problem: F22022 using algorithm: Model, on the: 20 trial
# Solving problem: F22022 using algorithm: Model, on the: 21 trial
# Solving problem: F22022 using algorithm: Model, on the: 22 trial
# Solving problem: F22022 using algorithm: Model, on the: 23 trial
# Solving problem: F22022 using algorithm: Model, on the: 24 trial
# Solving problem: F22022 using algorithm: Model, on the: 25 trial
# Solving problem: F32022 using algorithm: Model, on the: 1 trial
# Solving problem: F32022 using algorithm: Model, on the: 2 trial
# Solving problem: F32022 using algorithm: Model, on the: 3 trial
# Solving problem: F32022 using algorithm: Model, on the: 4 trial
# Solving problem: F32022 using algorithm: Model, on the: 5 trial
# Solving problem: F32022 using algorithm: Model, on the: 6 trial
# Solving problem: F32022 using algorithm: Model, on the: 7 trial
# Solving problem: F32022 using algorithm: Model, on the: 8 trial
# Solving problem: F32022 using algorithm: Model, on the: 9 trial
# Solving problem: F32022 using algorithm: Model, on the: 10 trial
# Solving problem: F32022 using algorithm: Model, on the: 11 trial
# Solving problem: F32022 using algorithm: Model, on the: 12 trial
# Solving problem: F32022 using algorithm: Model, on the: 13 trial
# Solving problem: F32022 using algorithm: Model, on the: 14 trial
# Solving problem: F32022 using algorithm: Model, on the: 15 trial
# Solving problem: F32022 using algorithm: Model, on the: 16 trial
# Solving problem: F32022 using algorithm: Model, on the: 17 trial
# Solving problem: F32022 using algorithm: Model, on the: 18 trial
# Solving problem: F32022 using algorithm: Model, on the: 19 trial
# Solving problem: F32022 using algorithm: Model, on the: 20 trial
# Solving problem: F32022 using algorithm: Model, on the: 21 trial
# Solving problem: F32022 using algorithm: Model, on the: 22 trial
# Solving problem: F32022 using algorithm: Model, on the: 23 trial
# Solving problem: F32022 using algorithm: Model, on the: 24 trial
# Solving problem: F32022 using algorithm: Model, on the: 25 trial
# Solving problem: F42022 using algorithm: Model, on the: 1 trial
# Solving problem: F42022 using algorithm: Model, on the: 2 trial
# Solving problem: F42022 using algorithm: Model, on the: 3 trial
# Solving problem: F42022 using algorithm: Model, on the: 4 trial
# Solving problem: F42022 using algorithm: Model, on the: 5 trial
# Solving problem: F42022 using algorithm: Model, on the: 6 trial
# Solving problem: F42022 using algorithm: Model, on the: 7 trial
# Solving problem: F42022 using algorithm: Model, on the: 8 trial
# Solving problem: F42022 using algorithm: Model, on the: 9 trial
# Solving problem: F42022 using algorithm: Model, on the: 10 trial
# Solving problem: F42022 using algorithm: Model, on the: 11 trial
# Solving problem: F42022 using algorithm: Model, on the: 12 trial
# Solving problem: F42022 using algorithm: Model, on the: 13 trial
# Solving problem: F42022 using algorithm: Model, on the: 14 trial
# Solving problem: F42022 using algorithm: Model, on the: 15 trial
# Solving problem: F42022 using algorithm: Model, on the: 16 trial
# Solving problem: F42022 using algorithm: Model, on the: 17 trial
# Solving problem: F42022 using algorithm: Model, on the: 18 trial
# Solving problem: F42022 using algorithm: Model, on the: 19 trial
# Solving problem: F42022 using algorithm: Model, on the: 20 trial
# Solving problem: F42022 using algorithm: Model, on the: 21 trial
# Solving problem: F42022 using algorithm: Model, on the: 22 trial
# Solving problem: F42022 using algorithm: Model, on the: 23 trial
# Solving problem: F42022 using algorithm: Model, on the: 24 trial
# Solving problem: F42022 using algorithm: Model, on the: 25 trial
# Solving problem: F52022 using algorithm: Model, on the: 1 trial
# Solving problem: F52022 using algorithm: Model, on the: 2 trial
# Solving problem: F52022 using algorithm: Model, on the: 3 trial
# Solving problem: F52022 using algorithm: Model, on the: 4 trial
# Solving problem: F52022 using algorithm: Model, on the: 5 trial
# Solving problem: F52022 using algorithm: Model, on the: 6 trial
# Solving problem: F52022 using algorithm: Model, on the: 7 trial
# Solving problem: F52022 using algorithm: Model, on the: 8 trial
# Solving problem: F52022 using algorithm: Model, on the: 9 trial
# Solving problem: F52022 using algorithm: Model, on the: 10 trial
# Solving problem: F52022 using algorithm: Model, on the: 11 trial
# Solving problem: F52022 using algorithm: Model, on the: 12 trial
# Solving problem: F52022 using algorithm: Model, on the: 13 trial
# Solving problem: F52022 using algorithm: Model, on the: 14 trial
# Solving problem: F52022 using algorithm: Model, on the: 15 trial
# Solving problem: F52022 using algorithm: Model, on the: 16 trial
# Solving problem: F52022 using algorithm: Model, on the: 17 trial
# Solving problem: F52022 using algorithm: Model, on the: 18 trial
# Solving problem: F52022 using algorithm: Model, on the: 19 trial
# Solving problem: F52022 using algorithm: Model, on the: 20 trial
# Solving problem: F52022 using algorithm: Model, on the: 21 trial
# Solving problem: F52022 using algorithm: Model, on the: 22 trial
# Solving problem: F52022 using algorithm: Model, on the: 23 trial
# Solving problem: F52022 using algorithm: Model, on the: 24 trial
# Solving problem: F52022 using algorithm: Model, on the: 25 trial
# Solving problem: F62022 using algorithm: Model, on the: 1 trial
# Solving problem: F62022 using algorithm: Model, on the: 2 trial
# Solving problem: F62022 using algorithm: Model, on the: 3 trial
# Solving problem: F62022 using algorithm: Model, on the: 4 trial
# Solving problem: F62022 using algorithm: Model, on the: 5 trial
# Solving problem: F62022 using algorithm: Model, on the: 6 trial
# Solving problem: F62022 using algorithm: Model, on the: 7 trial
# Solving problem: F62022 using algorithm: Model, on the: 8 trial
# Solving problem: F62022 using algorithm: Model, on the: 9 trial
# Solving problem: F62022 using algorithm: Model, on the: 10 trial
# Solving problem: F62022 using algorithm: Model, on the: 11 trial
# Solving problem: F62022 using algorithm: Model, on the: 12 trial
# Solving problem: F62022 using algorithm: Model, on the: 13 trial
# Solving problem: F62022 using algorithm: Model, on the: 14 trial
# Solving problem: F62022 using algorithm: Model, on the: 15 trial
# Solving problem: F62022 using algorithm: Model, on the: 16 trial
# Solving problem: F62022 using algorithm: Model, on the: 17 trial
# Solving problem: F62022 using algorithm: Model, on the: 18 trial
# Solving problem: F62022 using algorithm: Model, on the: 19 trial
# Solving problem: F62022 using algorithm: Model, on the: 20 trial
# Solving problem: F62022 using algorithm: Model, on the: 21 trial
# Solving problem: F62022 using algorithm: Model, on the: 22 trial
# Solving problem: F62022 using algorithm: Model, on the: 23 trial
# Solving problem: F62022 using algorithm: Model, on the: 24 trial
# Solving problem: F62022 using algorithm: Model, on the: 25 trial
# Solving problem: F72022 using algorithm: Model, on the: 1 trial
# Solving problem: F72022 using algorithm: Model, on the: 2 trial
# Solving problem: F72022 using algorithm: Model, on the: 3 trial
# Solving problem: F72022 using algorithm: Model, on the: 4 trial
# Solving problem: F72022 using algorithm: Model, on the: 5 trial
# Solving problem: F72022 using algorithm: Model, on the: 6 trial
# Solving problem: F72022 using algorithm: Model, on the: 7 trial
# Solving problem: F72022 using algorithm: Model, on the: 8 trial
# Solving problem: F72022 using algorithm: Model, on the: 9 trial
# Solving problem: F72022 using algorithm: Model, on the: 10 trial
# Solving problem: F72022 using algorithm: Model, on the: 11 trial
# Solving problem: F72022 using algorithm: Model, on the: 12 trial
# Solving problem: F72022 using algorithm: Model, on the: 13 trial
# Solving problem: F72022 using algorithm: Model, on the: 14 trial
# Solving problem: F72022 using algorithm: Model, on the: 15 trial
# Solving problem: F72022 using algorithm: Model, on the: 16 trial
# Solving problem: F72022 using algorithm: Model, on the: 17 trial
# Solving problem: F72022 using algorithm: Model, on the: 18 trial
# Solving problem: F72022 using algorithm: Model, on the: 19 trial
# Solving problem: F72022 using algorithm: Model, on the: 20 trial
# Solving problem: F72022 using algorithm: Model, on the: 21 trial
# Solving problem: F72022 using algorithm: Model, on the: 22 trial
# Solving problem: F72022 using algorithm: Model, on the: 23 trial
# Solving problem: F72022 using algorithm: Model, on the: 24 trial
# Solving problem: F72022 using algorithm: Model, on the: 25 trial
# Solving problem: F82022 using algorithm: Model, on the: 1 trial
# Solving problem: F82022 using algorithm: Model, on the: 2 trial
# Solving problem: F82022 using algorithm: Model, on the: 3 trial
# Solving problem: F82022 using algorithm: Model, on the: 4 trial
# Solving problem: F82022 using algorithm: Model, on the: 5 trial
# Solving problem: F82022 using algorithm: Model, on the: 6 trial
# Solving problem: F82022 using algorithm: Model, on the: 7 trial
# Solving problem: F82022 using algorithm: Model, on the: 8 trial
# Solving problem: F82022 using algorithm: Model, on the: 9 trial
# Solving problem: F82022 using algorithm: Model, on the: 10 trial
# Solving problem: F82022 using algorithm: Model, on the: 11 trial
# Solving problem: F82022 using algorithm: Model, on the: 12 trial
# Solving problem: F82022 using algorithm: Model, on the: 13 trial
# Solving problem: F82022 using algorithm: Model, on the: 14 trial
# Solving problem: F82022 using algorithm: Model, on the: 15 trial
# Solving problem: F82022 using algorithm: Model, on the: 16 trial
# Solving problem: F82022 using algorithm: Model, on the: 17 trial
# Solving problem: F82022 using algorithm: Model, on the: 18 trial
# Solving problem: F82022 using algorithm: Model, on the: 19 trial
# Solving problem: F82022 using algorithm: Model, on the: 20 trial
# Solving problem: F82022 using algorithm: Model, on the: 21 trial
# Solving problem: F82022 using algorithm: Model, on the: 22 trial
# Solving problem: F82022 using algorithm: Model, on the: 23 trial
# Solving problem: F82022 using algorithm: Model, on the: 24 trial
# Solving problem: F82022 using algorithm: Model, on the: 25 trial
# Solving problem: F92022 using algorithm: Model, on the: 1 trial
# Solving problem: F92022 using algorithm: Model, on the: 2 trial
# Solving problem: F92022 using algorithm: Model, on the: 3 trial
# Solving problem: F92022 using algorithm: Model, on the: 4 trial
# Solving problem: F92022 using algorithm: Model, on the: 5 trial
# Solving problem: F92022 using algorithm: Model, on the: 6 trial
# Solving problem: F92022 using algorithm: Model, on the: 7 trial
# Solving problem: F92022 using algorithm: Model, on the: 8 trial
# Solving problem: F92022 using algorithm: Model, on the: 9 trial
# Solving problem: F92022 using algorithm: Model, on the: 10 trial
# Solving problem: F92022 using algorithm: Model, on the: 11 trial
# Solving problem: F92022 using algorithm: Model, on the: 12 trial
# Solving problem: F92022 using algorithm: Model, on the: 13 trial
# Solving problem: F92022 using algorithm: Model, on the: 14 trial
# Solving problem: F92022 using algorithm: Model, on the: 15 trial
# Solving problem: F92022 using algorithm: Model, on the: 16 trial
# Solving problem: F92022 using algorithm: Model, on the: 17 trial
# Solving problem: F92022 using algorithm: Model, on the: 18 trial
# Solving problem: F92022 using algorithm: Model, on the: 19 trial
# Solving problem: F92022 using algorithm: Model, on the: 20 trial
# Solving problem: F92022 using algorithm: Model, on the: 21 trial
# Solving problem: F92022 using algorithm: Model, on the: 22 trial
# Solving problem: F92022 using algorithm: Model, on the: 23 trial
# Solving problem: F92022 using algorithm: Model, on the: 24 trial
# Solving problem: F92022 using algorithm: Model, on the: 25 trial
# Solving problem: F102022 using algorithm: Model, on the: 1 trial
# Solving problem: F102022 using algorithm: Model, on the: 2 trial
# Solving problem: F102022 using algorithm: Model, on the: 3 trial
# Solving problem: F102022 using algorithm: Model, on the: 4 trial
# Solving problem: F102022 using algorithm: Model, on the: 5 trial
# Solving problem: F102022 using algorithm: Model, on the: 6 trial
# Solving problem: F102022 using algorithm: Model, on the: 7 trial
# Solving problem: F102022 using algorithm: Model, on the: 8 trial
# Solving problem: F102022 using algorithm: Model, on the: 9 trial
# Solving problem: F102022 using algorithm: Model, on the: 10 trial
# Solving problem: F102022 using algorithm: Model, on the: 11 trial
# Solving problem: F102022 using algorithm: Model, on the: 12 trial
# Solving problem: F102022 using algorithm: Model, on the: 13 trial
# Solving problem: F102022 using algorithm: Model, on the: 14 trial
# Solving problem: F102022 using algorithm: Model, on the: 15 trial
# Solving problem: F102022 using algorithm: Model, on the: 16 trial
# Solving problem: F102022 using algorithm: Model, on the: 17 trial
# Solving problem: F102022 using algorithm: Model, on the: 18 trial
# Solving problem: F102022 using algorithm: Model, on the: 19 trial
# Solving problem: F102022 using algorithm: Model, on the: 20 trial
# Solving problem: F102022 using algorithm: Model, on the: 21 trial
# Solving problem: F102022 using algorithm: Model, on the: 22 trial
# Solving problem: F102022 using algorithm: Model, on the: 23 trial
# Solving problem: F102022 using algorithm: Model, on the: 24 trial
# Solving problem: F102022 using algorithm: Model, on the: 25 trial
# Solving problem: F112022 using algorithm: Model, on the: 1 trial
# Solving problem: F112022 using algorithm: Model, on the: 2 trial
# Solving problem: F112022 using algorithm: Model, on the: 3 trial
# Solving problem: F112022 using algorithm: Model, on the: 4 trial
# Solving problem: F112022 using algorithm: Model, on the: 5 trial
# Solving problem: F112022 using algorithm: Model, on the: 6 trial
# Solving problem: F112022 using algorithm: Model, on the: 7 trial
# Solving problem: F112022 using algorithm: Model, on the: 8 trial
# Solving problem: F112022 using algorithm: Model, on the: 9 trial
# Solving problem: F112022 using algorithm: Model, on the: 10 trial
# Solving problem: F112022 using algorithm: Model, on the: 11 trial
# Solving problem: F112022 using algorithm: Model, on the: 12 trial
# Solving problem: F112022 using algorithm: Model, on the: 13 trial
# Solving problem: F112022 using algorithm: Model, on the: 14 trial
# Solving problem: F112022 using algorithm: Model, on the: 15 trial
# Solving problem: F112022 using algorithm: Model, on the: 16 trial
# Solving problem: F112022 using algorithm: Model, on the: 17 trial
# Solving problem: F112022 using algorithm: Model, on the: 18 trial
# Solving problem: F112022 using algorithm: Model, on the: 19 trial
# Solving problem: F112022 using algorithm: Model, on the: 20 trial
# Solving problem: F112022 using algorithm: Model, on the: 21 trial
# Solving problem: F112022 using algorithm: Model, on the: 22 trial
# Solving problem: F112022 using algorithm: Model, on the: 23 trial
# Solving problem: F112022 using algorithm: Model, on the: 24 trial
# Solving problem: F112022 using algorithm: Model, on the: 25 trial
# Solving problem: F122022 using algorithm: Model, on the: 1 trial
# Solving problem: F122022 using algorithm: Model, on the: 2 trial
# Solving problem: F122022 using algorithm: Model, on the: 3 trial
# Solving problem: F122022 using algorithm: Model, on the: 4 trial
# Solving problem: F122022 using algorithm: Model, on the: 5 trial
# Solving problem: F122022 using algorithm: Model, on the: 6 trial
# Solving problem: F122022 using algorithm: Model, on the: 7 trial
# Solving problem: F122022 using algorithm: Model, on the: 8 trial
# Solving problem: F122022 using algorithm: Model, on the: 9 trial
# Solving problem: F122022 using algorithm: Model, on the: 10 trial
# Solving problem: F122022 using algorithm: Model, on the: 11 trial
# Solving problem: F122022 using algorithm: Model, on the: 12 trial
# Solving problem: F122022 using algorithm: Model, on the: 13 trial
# Solving problem: F122022 using algorithm: Model, on the: 14 trial
# Solving problem: F122022 using algorithm: Model, on the: 15 trial
# Solving problem: F122022 using algorithm: Model, on the: 16 trial
# Solving problem: F122022 using algorithm: Model, on the: 17 trial
# Solving problem: F122022 using algorithm: Model, on the: 18 trial
# Solving problem: F122022 using algorithm: Model, on the: 19 trial
# Solving problem: F122022 using algorithm: Model, on the: 20 trial
# Solving problem: F122022 using algorithm: Model, on the: 21 trial
# Solving problem: F122022 using algorithm: Model, on the: 22 trial
# Solving problem: F122022 using algorithm: Model, on the: 23 trial
# Solving problem: F122022 using algorithm: Model, on the: 24 trial
# Solving problem: F122022 using algorithm: Model, on the: 25 trial
