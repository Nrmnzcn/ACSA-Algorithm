# %%
# fundamental libraries
import numpy as np
import pandas as pd

# utils
from utils.save_result import *
from utils.visualization import *
from utils.multitask import *
from utils.test_functions import *
from utils.engineering_problem import *
from utils.ourmodel import *
from utils.optimizers import *

# %% [markdown]
# ## Define Test Functions

# %%
Fnames, Ffunctions, Fproblems, Flatexs = classical_test_function()
Cnames, Cfunctions, Cproblems, Clatexs = cec22_test_function_with_bias(dimension=10)

# %%
Ffunctions
# Out:
# [<opfunu.name_based.a_func.Ackley02 at 0x1d9f5a5c3b0>,
#  <opfunu.name_based.b_func.Brent at 0x1d9f5a5c800>,
#  <opfunu.name_based.c_func.ChungReynolds at 0x1d9f5a5c650>,
#  <opfunu.name_based.c_func.Cigar at 0x1d9f5a5c7d0>,
#  <opfunu.name_based.m_func.Matyas at 0x1d9f5a5c770>,
#  <opfunu.name_based.l_func.Leon at 0x1d9f5a415e0>,
#  <opfunu.name_based.m_func.Michalewicz at 0x1d9a6864e30>,
#  <opfunu.name_based.c_func.CrossInTray at 0x1d9a6864440>,
#  <opfunu.name_based.h_func.Hosaki at 0x1d9a6e4b860>,
#  <opfunu.name_based.l_func.Langermann at 0x1d9a6b88260>,
#  <opfunu.name_based.l_func.Levy05 at 0x1d9a6ad9ee0>,
#  <opfunu.name_based.m_func.Mishra05 at 0x1d9a6987bf0>,
#  <opfunu.name_based.a_func.Alpine02 at 0x1d9a6767440>,
#  <opfunu.name_based.h_func.Hansen at 0x1d9a6b61400>,
#  <opfunu.name_based.h_func.Himmelblau at 0x1d9a6a314f0>,
#  <opfunu.name_based.c_func.Chichinadze at 0x1d9a6df0440>]

# %% [markdown]
# ## Define Models

# %% [markdown]
# * Atom Search Optimization (ASO)
# * Chernobyl Disaster Optimizer (CDO)
# * Electromagnetic Field Optimization (EFO)
# * Equilibrium Optimizer (EO)
# * Henry Gas Solubility Optimization (HGSO)
# * Multi-Verse Optimizer (MVO)
# * Nuclear Reaction Optimization (NRO)
# * Simulated Annealing (SA)
# * Wind Driven Optimization (WDO)

# %%
aso, cdo, efo, eo, hgso, mvo, nro, sa, wdo = physics_based()
list_models = [aso, cdo, efo, eo, hgso, mvo, nro, sa, wdo]

# %%
eh = 0.6
en = 1.8
sh = 0.3
sn = 0.002
nh_rate=0.2
scale=0.1

epoch = 200
pop_size = 100

acsa = Model(epoch, pop_size, eh, en, sh, sn, nh_rate, scale)

# %% [markdown]
# ## Run Multitask

# %% [markdown]
# #### CLASSICAL TEST FUNCTION

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=list_models, problems=Fproblems)
    multitask.execute(n_trials=25, save_path="history/physics/classic", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Ackley2 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Brent using algorithm: OriginalASO, on the: 25 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 1 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 2 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 3 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 4 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 5 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 6 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 7 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 8 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 9 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 10 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 11 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 12 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 13 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 14 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 15 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 16 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 17 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 18 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 19 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 20 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 21 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 22 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 23 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 24 trial
# Solving problem: ChungReynolds using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Cigar using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Matyas using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Leon using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Michalewicz using algorithm: OriginalASO, on the: 25 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 1 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 2 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 3 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 4 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 5 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 6 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 7 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 8 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 9 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 10 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 11 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 12 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 13 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 14 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 15 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 16 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 17 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 18 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 19 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 20 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 21 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 22 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 23 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 24 trial
# Solving problem: CrossInTray using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Hosaki using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Langermann using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Levy5 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Mishra5 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Alpine2 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Hansen using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Himmelblau using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 1 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 2 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 3 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 4 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 5 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 6 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 7 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 8 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 9 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 10 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 11 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 12 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 13 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 14 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 15 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 16 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 17 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 18 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 19 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 20 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 21 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 22 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 23 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 24 trial
# Solving problem: Chichinadze using algorithm: OriginalASO, on the: 25 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: Ackley2 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: Brent using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: ChungReynolds using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: Cigar using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: Matyas using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: Leon using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: Michalewicz using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: CrossInTray using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: Hosaki using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: Langermann using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: Levy5 using algorithm: OriginalCDO, on the: 13 trial
# ...
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: CrossInTray using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: Hosaki using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: Langermann using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: Levy5 using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: Mishra5 using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: Alpine2 using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: Hansen using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: Himmelblau using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: Chichinadze using algorithm: OriginalWDO, on the: 25 trial

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=[acsa], problems=Fproblems)
    multitask.execute(n_trials=25, save_path="history/physics/classic", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: Ackley2 using algorithm: Model, on the: 1 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 2 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 3 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 4 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 5 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 6 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 7 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 8 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 9 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 10 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 11 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 12 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 13 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 14 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 15 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 16 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 17 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 18 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 19 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 20 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 21 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 22 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 23 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 24 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 25 trial
# Solving problem: Brent using algorithm: Model, on the: 1 trial
# Solving problem: Brent using algorithm: Model, on the: 2 trial
# Solving problem: Brent using algorithm: Model, on the: 3 trial
# Solving problem: Brent using algorithm: Model, on the: 4 trial
# Solving problem: Brent using algorithm: Model, on the: 5 trial
# Solving problem: Brent using algorithm: Model, on the: 6 trial
# Solving problem: Brent using algorithm: Model, on the: 7 trial
# Solving problem: Brent using algorithm: Model, on the: 8 trial
# Solving problem: Brent using algorithm: Model, on the: 9 trial
# Solving problem: Brent using algorithm: Model, on the: 10 trial
# Solving problem: Brent using algorithm: Model, on the: 11 trial
# Solving problem: Brent using algorithm: Model, on the: 12 trial
# Solving problem: Brent using algorithm: Model, on the: 13 trial
# Solving problem: Brent using algorithm: Model, on the: 14 trial
# Solving problem: Brent using algorithm: Model, on the: 15 trial
# Solving problem: Brent using algorithm: Model, on the: 16 trial
# Solving problem: Brent using algorithm: Model, on the: 17 trial
# Solving problem: Brent using algorithm: Model, on the: 18 trial
# Solving problem: Brent using algorithm: Model, on the: 19 trial
# Solving problem: Brent using algorithm: Model, on the: 20 trial
# Solving problem: Brent using algorithm: Model, on the: 21 trial
# Solving problem: Brent using algorithm: Model, on the: 22 trial
# Solving problem: Brent using algorithm: Model, on the: 23 trial
# Solving problem: Brent using algorithm: Model, on the: 24 trial
# Solving problem: Brent using algorithm: Model, on the: 25 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 1 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 2 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 3 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 4 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 5 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 6 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 7 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 8 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 9 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 10 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 11 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 12 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 13 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 14 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 15 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 16 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 17 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 18 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 19 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 20 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 21 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 22 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 23 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 24 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 25 trial
# Solving problem: Cigar using algorithm: Model, on the: 1 trial
# Solving problem: Cigar using algorithm: Model, on the: 2 trial
# Solving problem: Cigar using algorithm: Model, on the: 3 trial
# Solving problem: Cigar using algorithm: Model, on the: 4 trial
# Solving problem: Cigar using algorithm: Model, on the: 5 trial
# Solving problem: Cigar using algorithm: Model, on the: 6 trial
# Solving problem: Cigar using algorithm: Model, on the: 7 trial
# Solving problem: Cigar using algorithm: Model, on the: 8 trial
# Solving problem: Cigar using algorithm: Model, on the: 9 trial
# Solving problem: Cigar using algorithm: Model, on the: 10 trial
# Solving problem: Cigar using algorithm: Model, on the: 11 trial
# Solving problem: Cigar using algorithm: Model, on the: 12 trial
# Solving problem: Cigar using algorithm: Model, on the: 13 trial
# Solving problem: Cigar using algorithm: Model, on the: 14 trial
# Solving problem: Cigar using algorithm: Model, on the: 15 trial
# Solving problem: Cigar using algorithm: Model, on the: 16 trial
# Solving problem: Cigar using algorithm: Model, on the: 17 trial
# Solving problem: Cigar using algorithm: Model, on the: 18 trial
# Solving problem: Cigar using algorithm: Model, on the: 19 trial
# Solving problem: Cigar using algorithm: Model, on the: 20 trial
# Solving problem: Cigar using algorithm: Model, on the: 21 trial
# Solving problem: Cigar using algorithm: Model, on the: 22 trial
# Solving problem: Cigar using algorithm: Model, on the: 23 trial
# Solving problem: Cigar using algorithm: Model, on the: 24 trial
# Solving problem: Cigar using algorithm: Model, on the: 25 trial
# Solving problem: Matyas using algorithm: Model, on the: 1 trial
# Solving problem: Matyas using algorithm: Model, on the: 2 trial
# Solving problem: Matyas using algorithm: Model, on the: 3 trial
# Solving problem: Matyas using algorithm: Model, on the: 4 trial
# Solving problem: Matyas using algorithm: Model, on the: 5 trial
# Solving problem: Matyas using algorithm: Model, on the: 6 trial
# Solving problem: Matyas using algorithm: Model, on the: 7 trial
# Solving problem: Matyas using algorithm: Model, on the: 8 trial
# Solving problem: Matyas using algorithm: Model, on the: 9 trial
# Solving problem: Matyas using algorithm: Model, on the: 10 trial
# Solving problem: Matyas using algorithm: Model, on the: 11 trial
# Solving problem: Matyas using algorithm: Model, on the: 12 trial
# Solving problem: Matyas using algorithm: Model, on the: 13 trial
# Solving problem: Matyas using algorithm: Model, on the: 14 trial
# Solving problem: Matyas using algorithm: Model, on the: 15 trial
# Solving problem: Matyas using algorithm: Model, on the: 16 trial
# Solving problem: Matyas using algorithm: Model, on the: 17 trial
# Solving problem: Matyas using algorithm: Model, on the: 18 trial
# Solving problem: Matyas using algorithm: Model, on the: 19 trial
# Solving problem: Matyas using algorithm: Model, on the: 20 trial
# Solving problem: Matyas using algorithm: Model, on the: 21 trial
# Solving problem: Matyas using algorithm: Model, on the: 22 trial
# Solving problem: Matyas using algorithm: Model, on the: 23 trial
# Solving problem: Matyas using algorithm: Model, on the: 24 trial
# Solving problem: Matyas using algorithm: Model, on the: 25 trial
# Solving problem: Leon using algorithm: Model, on the: 1 trial
# Solving problem: Leon using algorithm: Model, on the: 2 trial
# Solving problem: Leon using algorithm: Model, on the: 3 trial
# Solving problem: Leon using algorithm: Model, on the: 4 trial
# Solving problem: Leon using algorithm: Model, on the: 5 trial
# Solving problem: Leon using algorithm: Model, on the: 6 trial
# Solving problem: Leon using algorithm: Model, on the: 7 trial
# Solving problem: Leon using algorithm: Model, on the: 8 trial
# Solving problem: Leon using algorithm: Model, on the: 9 trial
# Solving problem: Leon using algorithm: Model, on the: 10 trial
# Solving problem: Leon using algorithm: Model, on the: 11 trial
# Solving problem: Leon using algorithm: Model, on the: 12 trial
# Solving problem: Leon using algorithm: Model, on the: 13 trial
# Solving problem: Leon using algorithm: Model, on the: 14 trial
# Solving problem: Leon using algorithm: Model, on the: 15 trial
# Solving problem: Leon using algorithm: Model, on the: 16 trial
# Solving problem: Leon using algorithm: Model, on the: 17 trial
# Solving problem: Leon using algorithm: Model, on the: 18 trial
# Solving problem: Leon using algorithm: Model, on the: 19 trial
# Solving problem: Leon using algorithm: Model, on the: 20 trial
# Solving problem: Leon using algorithm: Model, on the: 21 trial
# Solving problem: Leon using algorithm: Model, on the: 22 trial
# Solving problem: Leon using algorithm: Model, on the: 23 trial
# Solving problem: Leon using algorithm: Model, on the: 24 trial
# Solving problem: Leon using algorithm: Model, on the: 25 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 1 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 2 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 3 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 4 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 5 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 6 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 7 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 8 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 9 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 10 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 11 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 12 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 13 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 14 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 15 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 16 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 17 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 18 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 19 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 20 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 21 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 22 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 23 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 24 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 25 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 1 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 2 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 3 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 4 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 5 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 6 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 7 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 8 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 9 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 10 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 11 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 12 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 13 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 14 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 15 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 16 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 17 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 18 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 19 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 20 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 21 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 22 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 23 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 24 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 25 trial
# Solving problem: Hosaki using algorithm: Model, on the: 1 trial
# Solving problem: Hosaki using algorithm: Model, on the: 2 trial
# Solving problem: Hosaki using algorithm: Model, on the: 3 trial
# Solving problem: Hosaki using algorithm: Model, on the: 4 trial
# Solving problem: Hosaki using algorithm: Model, on the: 5 trial
# Solving problem: Hosaki using algorithm: Model, on the: 6 trial
# Solving problem: Hosaki using algorithm: Model, on the: 7 trial
# Solving problem: Hosaki using algorithm: Model, on the: 8 trial
# Solving problem: Hosaki using algorithm: Model, on the: 9 trial
# Solving problem: Hosaki using algorithm: Model, on the: 10 trial
# Solving problem: Hosaki using algorithm: Model, on the: 11 trial
# Solving problem: Hosaki using algorithm: Model, on the: 12 trial
# Solving problem: Hosaki using algorithm: Model, on the: 13 trial
# Solving problem: Hosaki using algorithm: Model, on the: 14 trial
# Solving problem: Hosaki using algorithm: Model, on the: 15 trial
# Solving problem: Hosaki using algorithm: Model, on the: 16 trial
# Solving problem: Hosaki using algorithm: Model, on the: 17 trial
# Solving problem: Hosaki using algorithm: Model, on the: 18 trial
# Solving problem: Hosaki using algorithm: Model, on the: 19 trial
# Solving problem: Hosaki using algorithm: Model, on the: 20 trial
# Solving problem: Hosaki using algorithm: Model, on the: 21 trial
# Solving problem: Hosaki using algorithm: Model, on the: 22 trial
# Solving problem: Hosaki using algorithm: Model, on the: 23 trial
# Solving problem: Hosaki using algorithm: Model, on the: 24 trial
# Solving problem: Hosaki using algorithm: Model, on the: 25 trial
# Solving problem: Langermann using algorithm: Model, on the: 1 trial
# Solving problem: Langermann using algorithm: Model, on the: 2 trial
# Solving problem: Langermann using algorithm: Model, on the: 3 trial
# Solving problem: Langermann using algorithm: Model, on the: 4 trial
# Solving problem: Langermann using algorithm: Model, on the: 5 trial
# Solving problem: Langermann using algorithm: Model, on the: 6 trial
# Solving problem: Langermann using algorithm: Model, on the: 7 trial
# Solving problem: Langermann using algorithm: Model, on the: 8 trial
# Solving problem: Langermann using algorithm: Model, on the: 9 trial
# Solving problem: Langermann using algorithm: Model, on the: 10 trial
# Solving problem: Langermann using algorithm: Model, on the: 11 trial
# Solving problem: Langermann using algorithm: Model, on the: 12 trial
# Solving problem: Langermann using algorithm: Model, on the: 13 trial
# Solving problem: Langermann using algorithm: Model, on the: 14 trial
# Solving problem: Langermann using algorithm: Model, on the: 15 trial
# Solving problem: Langermann using algorithm: Model, on the: 16 trial
# Solving problem: Langermann using algorithm: Model, on the: 17 trial
# Solving problem: Langermann using algorithm: Model, on the: 18 trial
# Solving problem: Langermann using algorithm: Model, on the: 19 trial
# Solving problem: Langermann using algorithm: Model, on the: 20 trial
# Solving problem: Langermann using algorithm: Model, on the: 21 trial
# Solving problem: Langermann using algorithm: Model, on the: 22 trial
# Solving problem: Langermann using algorithm: Model, on the: 23 trial
# Solving problem: Langermann using algorithm: Model, on the: 24 trial
# Solving problem: Langermann using algorithm: Model, on the: 25 trial
# Solving problem: Levy5 using algorithm: Model, on the: 1 trial
# Solving problem: Levy5 using algorithm: Model, on the: 2 trial
# Solving problem: Levy5 using algorithm: Model, on the: 3 trial
# Solving problem: Levy5 using algorithm: Model, on the: 4 trial
# Solving problem: Levy5 using algorithm: Model, on the: 5 trial
# Solving problem: Levy5 using algorithm: Model, on the: 6 trial
# Solving problem: Levy5 using algorithm: Model, on the: 7 trial
# Solving problem: Levy5 using algorithm: Model, on the: 8 trial
# Solving problem: Levy5 using algorithm: Model, on the: 9 trial
# Solving problem: Levy5 using algorithm: Model, on the: 10 trial
# Solving problem: Levy5 using algorithm: Model, on the: 11 trial
# Solving problem: Levy5 using algorithm: Model, on the: 12 trial
# Solving problem: Levy5 using algorithm: Model, on the: 13 trial
# Solving problem: Levy5 using algorithm: Model, on the: 14 trial
# Solving problem: Levy5 using algorithm: Model, on the: 15 trial
# Solving problem: Levy5 using algorithm: Model, on the: 16 trial
# Solving problem: Levy5 using algorithm: Model, on the: 17 trial
# Solving problem: Levy5 using algorithm: Model, on the: 18 trial
# Solving problem: Levy5 using algorithm: Model, on the: 19 trial
# Solving problem: Levy5 using algorithm: Model, on the: 20 trial
# Solving problem: Levy5 using algorithm: Model, on the: 21 trial
# Solving problem: Levy5 using algorithm: Model, on the: 22 trial
# Solving problem: Levy5 using algorithm: Model, on the: 23 trial
# Solving problem: Levy5 using algorithm: Model, on the: 24 trial
# Solving problem: Levy5 using algorithm: Model, on the: 25 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 1 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 2 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 3 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 4 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 5 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 6 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 7 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 8 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 9 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 10 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 11 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 12 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 13 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 14 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 15 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 16 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 17 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 18 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 19 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 20 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 21 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 22 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 23 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 24 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 25 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 1 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 2 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 3 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 4 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 5 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 6 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 7 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 8 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 9 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 10 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 11 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 12 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 13 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 14 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 15 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 16 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 17 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 18 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 19 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 20 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 21 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 22 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 23 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 24 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 25 trial
# Solving problem: Hansen using algorithm: Model, on the: 1 trial
# Solving problem: Hansen using algorithm: Model, on the: 2 trial
# Solving problem: Hansen using algorithm: Model, on the: 3 trial
# Solving problem: Hansen using algorithm: Model, on the: 4 trial
# Solving problem: Hansen using algorithm: Model, on the: 5 trial
# Solving problem: Hansen using algorithm: Model, on the: 6 trial
# Solving problem: Hansen using algorithm: Model, on the: 7 trial
# Solving problem: Hansen using algorithm: Model, on the: 8 trial
# Solving problem: Hansen using algorithm: Model, on the: 9 trial
# Solving problem: Hansen using algorithm: Model, on the: 10 trial
# Solving problem: Hansen using algorithm: Model, on the: 11 trial
# Solving problem: Hansen using algorithm: Model, on the: 12 trial
# Solving problem: Hansen using algorithm: Model, on the: 13 trial
# Solving problem: Hansen using algorithm: Model, on the: 14 trial
# Solving problem: Hansen using algorithm: Model, on the: 15 trial
# Solving problem: Hansen using algorithm: Model, on the: 16 trial
# Solving problem: Hansen using algorithm: Model, on the: 17 trial
# Solving problem: Hansen using algorithm: Model, on the: 18 trial
# Solving problem: Hansen using algorithm: Model, on the: 19 trial
# Solving problem: Hansen using algorithm: Model, on the: 20 trial
# Solving problem: Hansen using algorithm: Model, on the: 21 trial
# Solving problem: Hansen using algorithm: Model, on the: 22 trial
# Solving problem: Hansen using algorithm: Model, on the: 23 trial
# Solving problem: Hansen using algorithm: Model, on the: 24 trial
# Solving problem: Hansen using algorithm: Model, on the: 25 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 1 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 2 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 3 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 4 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 5 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 6 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 7 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 8 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 9 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 10 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 11 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 12 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 13 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 14 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 15 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 16 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 17 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 18 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 19 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 20 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 21 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 22 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 23 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 24 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 25 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 1 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 2 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 3 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 4 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 5 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 6 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 7 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 8 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 9 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 10 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 11 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 12 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 13 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 14 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 15 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 16 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 17 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 18 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 19 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 20 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 21 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 22 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 23 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 24 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 25 trial

# %% [markdown]
# #### CEC22 TEST FUNCTION

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=list_models, problems=Cproblems)
    multitask.execute(n_trials=25, save_path="history/physics/cec22", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: F12022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F12022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F22022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F32022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F42022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F52022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F62022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F72022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F82022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F92022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F102022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F112022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 1 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 2 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 3 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 4 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 5 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 6 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 7 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 8 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 9 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 10 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 11 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 12 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 13 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 14 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 15 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 16 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 17 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 18 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 19 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 20 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 21 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 22 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 23 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 24 trial
# Solving problem: F122022 using algorithm: OriginalASO, on the: 25 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F12022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F22022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F32022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F42022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F52022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F62022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F72022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F82022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F92022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F102022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F112022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 1 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 2 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 3 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 4 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 5 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 6 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 7 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 8 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 9 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 10 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 11 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 12 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 13 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 14 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 15 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 16 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 17 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 18 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 19 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 20 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 21 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 22 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 23 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 24 trial
# Solving problem: F122022 using algorithm: OriginalCDO, on the: 25 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 1 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 2 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 3 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 4 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 5 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 6 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 7 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 8 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 9 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 10 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 11 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 12 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 13 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 14 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 15 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 16 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 17 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 18 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 19 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 20 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 21 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 22 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 23 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 24 trial
# Solving problem: F12022 using algorithm: OriginalEFO, on the: 25 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 1 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 2 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 3 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 4 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 5 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 6 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 7 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 8 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 9 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 10 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 11 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 12 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 13 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 14 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 15 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 16 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 17 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 18 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 19 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 20 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 21 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 22 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 23 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 24 trial
# Solving problem: F22022 using algorithm: OriginalEFO, on the: 25 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 1 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 2 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 3 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 4 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 5 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 6 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 7 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 8 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 9 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 10 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 11 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 12 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 13 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 14 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 15 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 16 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 17 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 18 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 19 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 20 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 21 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 22 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 23 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 24 trial
# Solving problem: F32022 using algorithm: OriginalEFO, on the: 25 trial
# Solving problem: F42022 using algorithm: OriginalEFO, on the: 1 trial
# Solving problem: F42022 using algorithm: OriginalEFO, on the: 2 trial
# ...
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: F42022 using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: F52022 using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: F62022 using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: F72022 using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: F82022 using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: F92022 using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: F102022 using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: F112022 using algorithm: OriginalWDO, on the: 25 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 1 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 2 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 3 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 4 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 5 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 6 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 7 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 8 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 9 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 10 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 11 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 12 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 13 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 14 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 15 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 16 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 17 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 18 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 19 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 20 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 21 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 22 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 23 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 24 trial
# Solving problem: F122022 using algorithm: OriginalWDO, on the: 25 trial

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=[acsa], problems=Cproblems)
    multitask.execute(n_trials=25, save_path="history/physics/cec22", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: F12022 using algorithm: Model, on the: 1 trial
# Solving problem: F12022 using algorithm: Model, on the: 2 trial
# Solving problem: F12022 using algorithm: Model, on the: 3 trial
# Solving problem: F12022 using algorithm: Model, on the: 4 trial
# Solving problem: F12022 using algorithm: Model, on the: 5 trial
# Solving problem: F12022 using algorithm: Model, on the: 6 trial
# Solving problem: F12022 using algorithm: Model, on the: 7 trial
# Solving problem: F12022 using algorithm: Model, on the: 8 trial
# Solving problem: F12022 using algorithm: Model, on the: 9 trial
# Solving problem: F12022 using algorithm: Model, on the: 10 trial
# Solving problem: F12022 using algorithm: Model, on the: 11 trial
# Solving problem: F12022 using algorithm: Model, on the: 12 trial
# Solving problem: F12022 using algorithm: Model, on the: 13 trial
# Solving problem: F12022 using algorithm: Model, on the: 14 trial
# Solving problem: F12022 using algorithm: Model, on the: 15 trial
# Solving problem: F12022 using algorithm: Model, on the: 16 trial
# Solving problem: F12022 using algorithm: Model, on the: 17 trial
# Solving problem: F12022 using algorithm: Model, on the: 18 trial
# Solving problem: F12022 using algorithm: Model, on the: 19 trial
# Solving problem: F12022 using algorithm: Model, on the: 20 trial
# Solving problem: F12022 using algorithm: Model, on the: 21 trial
# Solving problem: F12022 using algorithm: Model, on the: 22 trial
# Solving problem: F12022 using algorithm: Model, on the: 23 trial
# Solving problem: F12022 using algorithm: Model, on the: 24 trial
# Solving problem: F12022 using algorithm: Model, on the: 25 trial
# Solving problem: F22022 using algorithm: Model, on the: 1 trial
# Solving problem: F22022 using algorithm: Model, on the: 2 trial
# Solving problem: F22022 using algorithm: Model, on the: 3 trial
# Solving problem: F22022 using algorithm: Model, on the: 4 trial
# Solving problem: F22022 using algorithm: Model, on the: 5 trial
# Solving problem: F22022 using algorithm: Model, on the: 6 trial
# Solving problem: F22022 using algorithm: Model, on the: 7 trial
# Solving problem: F22022 using algorithm: Model, on the: 8 trial
# Solving problem: F22022 using algorithm: Model, on the: 9 trial
# Solving problem: F22022 using algorithm: Model, on the: 10 trial
# Solving problem: F22022 using algorithm: Model, on the: 11 trial
# Solving problem: F22022 using algorithm: Model, on the: 12 trial
# Solving problem: F22022 using algorithm: Model, on the: 13 trial
# Solving problem: F22022 using algorithm: Model, on the: 14 trial
# Solving problem: F22022 using algorithm: Model, on the: 15 trial
# Solving problem: F22022 using algorithm: Model, on the: 16 trial
# Solving problem: F22022 using algorithm: Model, on the: 17 trial
# Solving problem: F22022 using algorithm: Model, on the: 18 trial
# Solving problem: F22022 using algorithm: Model, on the: 19 trial
# Solving problem: F22022 using algorithm: Model, on the: 20 trial
# Solving problem: F22022 using algorithm: Model, on the: 21 trial
# Solving problem: F22022 using algorithm: Model, on the: 22 trial
# Solving problem: F22022 using algorithm: Model, on the: 23 trial
# Solving problem: F22022 using algorithm: Model, on the: 24 trial
# Solving problem: F22022 using algorithm: Model, on the: 25 trial
# Solving problem: F32022 using algorithm: Model, on the: 1 trial
# Solving problem: F32022 using algorithm: Model, on the: 2 trial
# Solving problem: F32022 using algorithm: Model, on the: 3 trial
# Solving problem: F32022 using algorithm: Model, on the: 4 trial
# Solving problem: F32022 using algorithm: Model, on the: 5 trial
# Solving problem: F32022 using algorithm: Model, on the: 6 trial
# Solving problem: F32022 using algorithm: Model, on the: 7 trial
# Solving problem: F32022 using algorithm: Model, on the: 8 trial
# Solving problem: F32022 using algorithm: Model, on the: 9 trial
# Solving problem: F32022 using algorithm: Model, on the: 10 trial
# Solving problem: F32022 using algorithm: Model, on the: 11 trial
# Solving problem: F32022 using algorithm: Model, on the: 12 trial
# Solving problem: F32022 using algorithm: Model, on the: 13 trial
# Solving problem: F32022 using algorithm: Model, on the: 14 trial
# Solving problem: F32022 using algorithm: Model, on the: 15 trial
# Solving problem: F32022 using algorithm: Model, on the: 16 trial
# Solving problem: F32022 using algorithm: Model, on the: 17 trial
# Solving problem: F32022 using algorithm: Model, on the: 18 trial
# Solving problem: F32022 using algorithm: Model, on the: 19 trial
# Solving problem: F32022 using algorithm: Model, on the: 20 trial
# Solving problem: F32022 using algorithm: Model, on the: 21 trial
# Solving problem: F32022 using algorithm: Model, on the: 22 trial
# Solving problem: F32022 using algorithm: Model, on the: 23 trial
# Solving problem: F32022 using algorithm: Model, on the: 24 trial
# Solving problem: F32022 using algorithm: Model, on the: 25 trial
# Solving problem: F42022 using algorithm: Model, on the: 1 trial
# Solving problem: F42022 using algorithm: Model, on the: 2 trial
# Solving problem: F42022 using algorithm: Model, on the: 3 trial
# Solving problem: F42022 using algorithm: Model, on the: 4 trial
# Solving problem: F42022 using algorithm: Model, on the: 5 trial
# Solving problem: F42022 using algorithm: Model, on the: 6 trial
# Solving problem: F42022 using algorithm: Model, on the: 7 trial
# Solving problem: F42022 using algorithm: Model, on the: 8 trial
# Solving problem: F42022 using algorithm: Model, on the: 9 trial
# Solving problem: F42022 using algorithm: Model, on the: 10 trial
# Solving problem: F42022 using algorithm: Model, on the: 11 trial
# Solving problem: F42022 using algorithm: Model, on the: 12 trial
# Solving problem: F42022 using algorithm: Model, on the: 13 trial
# Solving problem: F42022 using algorithm: Model, on the: 14 trial
# Solving problem: F42022 using algorithm: Model, on the: 15 trial
# Solving problem: F42022 using algorithm: Model, on the: 16 trial
# Solving problem: F42022 using algorithm: Model, on the: 17 trial
# Solving problem: F42022 using algorithm: Model, on the: 18 trial
# Solving problem: F42022 using algorithm: Model, on the: 19 trial
# Solving problem: F42022 using algorithm: Model, on the: 20 trial
# Solving problem: F42022 using algorithm: Model, on the: 21 trial
# Solving problem: F42022 using algorithm: Model, on the: 22 trial
# Solving problem: F42022 using algorithm: Model, on the: 23 trial
# Solving problem: F42022 using algorithm: Model, on the: 24 trial
# Solving problem: F42022 using algorithm: Model, on the: 25 trial
# Solving problem: F52022 using algorithm: Model, on the: 1 trial
# Solving problem: F52022 using algorithm: Model, on the: 2 trial
# Solving problem: F52022 using algorithm: Model, on the: 3 trial
# Solving problem: F52022 using algorithm: Model, on the: 4 trial
# Solving problem: F52022 using algorithm: Model, on the: 5 trial
# Solving problem: F52022 using algorithm: Model, on the: 6 trial
# Solving problem: F52022 using algorithm: Model, on the: 7 trial
# Solving problem: F52022 using algorithm: Model, on the: 8 trial
# Solving problem: F52022 using algorithm: Model, on the: 9 trial
# Solving problem: F52022 using algorithm: Model, on the: 10 trial
# Solving problem: F52022 using algorithm: Model, on the: 11 trial
# Solving problem: F52022 using algorithm: Model, on the: 12 trial
# Solving problem: F52022 using algorithm: Model, on the: 13 trial
# Solving problem: F52022 using algorithm: Model, on the: 14 trial
# Solving problem: F52022 using algorithm: Model, on the: 15 trial
# Solving problem: F52022 using algorithm: Model, on the: 16 trial
# Solving problem: F52022 using algorithm: Model, on the: 17 trial
# Solving problem: F52022 using algorithm: Model, on the: 18 trial
# Solving problem: F52022 using algorithm: Model, on the: 19 trial
# Solving problem: F52022 using algorithm: Model, on the: 20 trial
# Solving problem: F52022 using algorithm: Model, on the: 21 trial
# Solving problem: F52022 using algorithm: Model, on the: 22 trial
# Solving problem: F52022 using algorithm: Model, on the: 23 trial
# Solving problem: F52022 using algorithm: Model, on the: 24 trial
# Solving problem: F52022 using algorithm: Model, on the: 25 trial
# Solving problem: F62022 using algorithm: Model, on the: 1 trial
# Solving problem: F62022 using algorithm: Model, on the: 2 trial
# Solving problem: F62022 using algorithm: Model, on the: 3 trial
# Solving problem: F62022 using algorithm: Model, on the: 4 trial
# Solving problem: F62022 using algorithm: Model, on the: 5 trial
# Solving problem: F62022 using algorithm: Model, on the: 6 trial
# Solving problem: F62022 using algorithm: Model, on the: 7 trial
# Solving problem: F62022 using algorithm: Model, on the: 8 trial
# Solving problem: F62022 using algorithm: Model, on the: 9 trial
# Solving problem: F62022 using algorithm: Model, on the: 10 trial
# Solving problem: F62022 using algorithm: Model, on the: 11 trial
# Solving problem: F62022 using algorithm: Model, on the: 12 trial
# Solving problem: F62022 using algorithm: Model, on the: 13 trial
# Solving problem: F62022 using algorithm: Model, on the: 14 trial
# Solving problem: F62022 using algorithm: Model, on the: 15 trial
# Solving problem: F62022 using algorithm: Model, on the: 16 trial
# Solving problem: F62022 using algorithm: Model, on the: 17 trial
# Solving problem: F62022 using algorithm: Model, on the: 18 trial
# Solving problem: F62022 using algorithm: Model, on the: 19 trial
# Solving problem: F62022 using algorithm: Model, on the: 20 trial
# Solving problem: F62022 using algorithm: Model, on the: 21 trial
# Solving problem: F62022 using algorithm: Model, on the: 22 trial
# Solving problem: F62022 using algorithm: Model, on the: 23 trial
# Solving problem: F62022 using algorithm: Model, on the: 24 trial
# Solving problem: F62022 using algorithm: Model, on the: 25 trial
# Solving problem: F72022 using algorithm: Model, on the: 1 trial
# Solving problem: F72022 using algorithm: Model, on the: 2 trial
# Solving problem: F72022 using algorithm: Model, on the: 3 trial
# Solving problem: F72022 using algorithm: Model, on the: 4 trial
# Solving problem: F72022 using algorithm: Model, on the: 5 trial
# Solving problem: F72022 using algorithm: Model, on the: 6 trial
# Solving problem: F72022 using algorithm: Model, on the: 7 trial
# Solving problem: F72022 using algorithm: Model, on the: 8 trial
# Solving problem: F72022 using algorithm: Model, on the: 9 trial
# Solving problem: F72022 using algorithm: Model, on the: 10 trial
# Solving problem: F72022 using algorithm: Model, on the: 11 trial
# Solving problem: F72022 using algorithm: Model, on the: 12 trial
# Solving problem: F72022 using algorithm: Model, on the: 13 trial
# Solving problem: F72022 using algorithm: Model, on the: 14 trial
# Solving problem: F72022 using algorithm: Model, on the: 15 trial
# Solving problem: F72022 using algorithm: Model, on the: 16 trial
# Solving problem: F72022 using algorithm: Model, on the: 17 trial
# Solving problem: F72022 using algorithm: Model, on the: 18 trial
# Solving problem: F72022 using algorithm: Model, on the: 19 trial
# Solving problem: F72022 using algorithm: Model, on the: 20 trial
# Solving problem: F72022 using algorithm: Model, on the: 21 trial
# Solving problem: F72022 using algorithm: Model, on the: 22 trial
# Solving problem: F72022 using algorithm: Model, on the: 23 trial
# Solving problem: F72022 using algorithm: Model, on the: 24 trial
# Solving problem: F72022 using algorithm: Model, on the: 25 trial
# Solving problem: F82022 using algorithm: Model, on the: 1 trial
# Solving problem: F82022 using algorithm: Model, on the: 2 trial
# Solving problem: F82022 using algorithm: Model, on the: 3 trial
# Solving problem: F82022 using algorithm: Model, on the: 4 trial
# Solving problem: F82022 using algorithm: Model, on the: 5 trial
# Solving problem: F82022 using algorithm: Model, on the: 6 trial
# Solving problem: F82022 using algorithm: Model, on the: 7 trial
# Solving problem: F82022 using algorithm: Model, on the: 8 trial
# Solving problem: F82022 using algorithm: Model, on the: 9 trial
# Solving problem: F82022 using algorithm: Model, on the: 10 trial
# Solving problem: F82022 using algorithm: Model, on the: 11 trial
# Solving problem: F82022 using algorithm: Model, on the: 12 trial
# Solving problem: F82022 using algorithm: Model, on the: 13 trial
# Solving problem: F82022 using algorithm: Model, on the: 14 trial
# Solving problem: F82022 using algorithm: Model, on the: 15 trial
# Solving problem: F82022 using algorithm: Model, on the: 16 trial
# Solving problem: F82022 using algorithm: Model, on the: 17 trial
# Solving problem: F82022 using algorithm: Model, on the: 18 trial
# Solving problem: F82022 using algorithm: Model, on the: 19 trial
# Solving problem: F82022 using algorithm: Model, on the: 20 trial
# Solving problem: F82022 using algorithm: Model, on the: 21 trial
# Solving problem: F82022 using algorithm: Model, on the: 22 trial
# Solving problem: F82022 using algorithm: Model, on the: 23 trial
# Solving problem: F82022 using algorithm: Model, on the: 24 trial
# Solving problem: F82022 using algorithm: Model, on the: 25 trial
# Solving problem: F92022 using algorithm: Model, on the: 1 trial
# Solving problem: F92022 using algorithm: Model, on the: 2 trial
# Solving problem: F92022 using algorithm: Model, on the: 3 trial
# Solving problem: F92022 using algorithm: Model, on the: 4 trial
# Solving problem: F92022 using algorithm: Model, on the: 5 trial
# Solving problem: F92022 using algorithm: Model, on the: 6 trial
# Solving problem: F92022 using algorithm: Model, on the: 7 trial
# Solving problem: F92022 using algorithm: Model, on the: 8 trial
# Solving problem: F92022 using algorithm: Model, on the: 9 trial
# Solving problem: F92022 using algorithm: Model, on the: 10 trial
# Solving problem: F92022 using algorithm: Model, on the: 11 trial
# Solving problem: F92022 using algorithm: Model, on the: 12 trial
# Solving problem: F92022 using algorithm: Model, on the: 13 trial
# Solving problem: F92022 using algorithm: Model, on the: 14 trial
# Solving problem: F92022 using algorithm: Model, on the: 15 trial
# Solving problem: F92022 using algorithm: Model, on the: 16 trial
# Solving problem: F92022 using algorithm: Model, on the: 17 trial
# Solving problem: F92022 using algorithm: Model, on the: 18 trial
# Solving problem: F92022 using algorithm: Model, on the: 19 trial
# Solving problem: F92022 using algorithm: Model, on the: 20 trial
# Solving problem: F92022 using algorithm: Model, on the: 21 trial
# Solving problem: F92022 using algorithm: Model, on the: 22 trial
# Solving problem: F92022 using algorithm: Model, on the: 23 trial
# Solving problem: F92022 using algorithm: Model, on the: 24 trial
# Solving problem: F92022 using algorithm: Model, on the: 25 trial
# Solving problem: F102022 using algorithm: Model, on the: 1 trial
# Solving problem: F102022 using algorithm: Model, on the: 2 trial
# Solving problem: F102022 using algorithm: Model, on the: 3 trial
# Solving problem: F102022 using algorithm: Model, on the: 4 trial
# Solving problem: F102022 using algorithm: Model, on the: 5 trial
# Solving problem: F102022 using algorithm: Model, on the: 6 trial
# Solving problem: F102022 using algorithm: Model, on the: 7 trial
# Solving problem: F102022 using algorithm: Model, on the: 8 trial
# Solving problem: F102022 using algorithm: Model, on the: 9 trial
# Solving problem: F102022 using algorithm: Model, on the: 10 trial
# Solving problem: F102022 using algorithm: Model, on the: 11 trial
# Solving problem: F102022 using algorithm: Model, on the: 12 trial
# Solving problem: F102022 using algorithm: Model, on the: 13 trial
# Solving problem: F102022 using algorithm: Model, on the: 14 trial
# Solving problem: F102022 using algorithm: Model, on the: 15 trial
# Solving problem: F102022 using algorithm: Model, on the: 16 trial
# Solving problem: F102022 using algorithm: Model, on the: 17 trial
# Solving problem: F102022 using algorithm: Model, on the: 18 trial
# Solving problem: F102022 using algorithm: Model, on the: 19 trial
# Solving problem: F102022 using algorithm: Model, on the: 20 trial
# Solving problem: F102022 using algorithm: Model, on the: 21 trial
# Solving problem: F102022 using algorithm: Model, on the: 22 trial
# Solving problem: F102022 using algorithm: Model, on the: 23 trial
# Solving problem: F102022 using algorithm: Model, on the: 24 trial
# Solving problem: F102022 using algorithm: Model, on the: 25 trial
# Solving problem: F112022 using algorithm: Model, on the: 1 trial
# Solving problem: F112022 using algorithm: Model, on the: 2 trial
# Solving problem: F112022 using algorithm: Model, on the: 3 trial
# Solving problem: F112022 using algorithm: Model, on the: 4 trial
# Solving problem: F112022 using algorithm: Model, on the: 5 trial
# Solving problem: F112022 using algorithm: Model, on the: 6 trial
# Solving problem: F112022 using algorithm: Model, on the: 7 trial
# Solving problem: F112022 using algorithm: Model, on the: 8 trial
# Solving problem: F112022 using algorithm: Model, on the: 9 trial
# Solving problem: F112022 using algorithm: Model, on the: 10 trial
# Solving problem: F112022 using algorithm: Model, on the: 11 trial
# Solving problem: F112022 using algorithm: Model, on the: 12 trial
# Solving problem: F112022 using algorithm: Model, on the: 13 trial
# Solving problem: F112022 using algorithm: Model, on the: 14 trial
# Solving problem: F112022 using algorithm: Model, on the: 15 trial
# Solving problem: F112022 using algorithm: Model, on the: 16 trial
# Solving problem: F112022 using algorithm: Model, on the: 17 trial
# Solving problem: F112022 using algorithm: Model, on the: 18 trial
# Solving problem: F112022 using algorithm: Model, on the: 19 trial
# Solving problem: F112022 using algorithm: Model, on the: 20 trial
# Solving problem: F112022 using algorithm: Model, on the: 21 trial
# Solving problem: F112022 using algorithm: Model, on the: 22 trial
# Solving problem: F112022 using algorithm: Model, on the: 23 trial
# Solving problem: F112022 using algorithm: Model, on the: 24 trial
# Solving problem: F112022 using algorithm: Model, on the: 25 trial
# Solving problem: F122022 using algorithm: Model, on the: 1 trial
# Solving problem: F122022 using algorithm: Model, on the: 2 trial
# Solving problem: F122022 using algorithm: Model, on the: 3 trial
# Solving problem: F122022 using algorithm: Model, on the: 4 trial
# Solving problem: F122022 using algorithm: Model, on the: 5 trial
# Solving problem: F122022 using algorithm: Model, on the: 6 trial
# Solving problem: F122022 using algorithm: Model, on the: 7 trial
# Solving problem: F122022 using algorithm: Model, on the: 8 trial
# Solving problem: F122022 using algorithm: Model, on the: 9 trial
# Solving problem: F122022 using algorithm: Model, on the: 10 trial
# Solving problem: F122022 using algorithm: Model, on the: 11 trial
# Solving problem: F122022 using algorithm: Model, on the: 12 trial
# Solving problem: F122022 using algorithm: Model, on the: 13 trial
# Solving problem: F122022 using algorithm: Model, on the: 14 trial
# Solving problem: F122022 using algorithm: Model, on the: 15 trial
# Solving problem: F122022 using algorithm: Model, on the: 16 trial
# Solving problem: F122022 using algorithm: Model, on the: 17 trial
# Solving problem: F122022 using algorithm: Model, on the: 18 trial
# Solving problem: F122022 using algorithm: Model, on the: 19 trial
# Solving problem: F122022 using algorithm: Model, on the: 20 trial
# Solving problem: F122022 using algorithm: Model, on the: 21 trial
# Solving problem: F122022 using algorithm: Model, on the: 22 trial
# Solving problem: F122022 using algorithm: Model, on the: 23 trial
# Solving problem: F122022 using algorithm: Model, on the: 24 trial
# Solving problem: F122022 using algorithm: Model, on the: 25 trial
