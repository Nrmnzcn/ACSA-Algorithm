# %%
# fundamental libraries
import numpy as np
import pandas as pd

# utils
from utils.save_result import *
from utils.visualization import *
from utils.multitask import *
from utils.test_functions import *
from utils.engineering_problem import *
from utils.ourmodel import *
from utils.optimizers import *

# %% [markdown]
# ## Define Test Functions

# %%
Fnames, Ffunctions, Fproblems, Flatexs = classical_test_function()
Cnames, Cfunctions, Cproblems, Clatexs = cec22_test_function_with_bias(dimension=10)

# %%
Ffunctions
# Out:
# [<opfunu.name_based.a_func.Ackley02 at 0x2e80b564a10>,
#  <opfunu.name_based.b_func.Brent at 0x2e80bbedca0>,
#  <opfunu.name_based.c_func.ChungReynolds at 0x2e80b564d10>,
#  <opfunu.name_based.c_func.Cigar at 0x2e870d41460>,
#  <opfunu.name_based.m_func.Matyas at 0x2e80b8598b0>,
#  <opfunu.name_based.l_func.Leon at 0x2e80b9e8cb0>,
#  <opfunu.name_based.m_func.Michalewicz at 0x2e80bb4fef0>,
#  <opfunu.name_based.c_func.CrossInTray at 0x2e80b5c88f0>,
#  <opfunu.name_based.h_func.Hosaki at 0x2e80bbcc800>,
#  <opfunu.name_based.l_func.Langermann at 0x2e80b5e9e20>,
#  <opfunu.name_based.l_func.Levy05 at 0x2e809ef4bf0>,
#  <opfunu.name_based.m_func.Mishra05 at 0x2e80b163d10>,
#  <opfunu.name_based.a_func.Alpine02 at 0x2e80b764830>,
#  <opfunu.name_based.h_func.Hansen at 0x2e80b5e89b0>,
#  <opfunu.name_based.h_func.Himmelblau at 0x2e80b564c80>,
#  <opfunu.name_based.c_func.Chichinadze at 0x2e80b564c50>]

# %% [markdown]
# ## Define Models

# %% [markdown]
# * Coral Reefs Optimization (CRO)
# * Differential Evolution (DE)
# * Evolution Strategies (ES)
# * Flower Pollination Algorithm (FPA)
# * Genetic Algorithm (GA)
# * Memetic Algorithm (MA)

# %%
cro, de, es, fpa, ga, ma = evolutionary_based()
list_models = [cro, de, es, fpa, ga, ma]

# %%
eh = 0.6
en = 1.8
sh = 0.3
sn = 0.002
nh_rate=0.2
scale=0.1

epoch = 200
pop_size = 100

acsa = Model(epoch, pop_size, eh, en, sh, sn, nh_rate, scale)

# %% [markdown]
# ## Run Multitask

# %% [markdown]
# #### CLASSICAL TEST FUNCTION

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=list_models, problems=Fproblems)
    multitask.execute(n_trials=25, save_path="history/evolutionary/classic", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Ackley2 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Brent using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: ChungReynolds using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Cigar using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Matyas using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Leon using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Michalewicz using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: CrossInTray using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Hosaki using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Langermann using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Levy5 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Mishra5 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Alpine2 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Hansen using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Himmelblau using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: Chichinadze using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 1 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 2 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 3 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 4 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 5 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 6 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 7 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 8 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 9 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 10 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 11 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 12 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 13 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 14 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 15 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 16 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 17 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 18 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 19 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 20 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 21 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 22 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 23 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 24 trial
# Solving problem: Ackley2 using algorithm: BaseDE, on the: 25 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 1 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 2 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 3 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 4 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 5 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 6 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 7 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 8 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 9 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 10 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 11 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 12 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 13 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 14 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 15 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 16 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 17 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 18 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 19 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 20 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 21 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 22 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 23 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 24 trial
# Solving problem: Brent using algorithm: BaseDE, on the: 25 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 1 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 2 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 3 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 4 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 5 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 6 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 7 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 8 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 9 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 10 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 11 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 12 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 13 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 14 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 15 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 16 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 17 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 18 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 19 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 20 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 21 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 22 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 23 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 24 trial
# Solving problem: ChungReynolds using algorithm: BaseDE, on the: 25 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 1 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 2 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 3 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 4 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 5 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 6 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 7 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 8 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 9 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 10 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 11 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 12 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 13 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 14 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 15 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 16 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 17 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 18 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 19 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 20 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 21 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 22 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 23 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 24 trial
# Solving problem: Cigar using algorithm: BaseDE, on the: 25 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 1 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 2 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 3 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 4 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 5 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 6 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 7 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 8 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 9 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 10 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 11 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 12 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 13 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 14 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 15 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 16 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 17 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 18 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 19 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 20 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 21 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 22 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 23 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 24 trial
# Solving problem: Matyas using algorithm: BaseDE, on the: 25 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 1 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 2 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 3 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 4 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 5 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 6 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 7 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 8 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 9 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 10 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 11 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 12 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 13 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 14 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 15 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 16 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 17 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 18 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 19 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 20 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 21 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 22 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 23 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 24 trial
# Solving problem: Leon using algorithm: BaseDE, on the: 25 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 1 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 2 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 3 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 4 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 5 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 6 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 7 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 8 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 9 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 10 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 11 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 12 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 13 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 14 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 15 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 16 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 17 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 18 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 19 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 20 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 21 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 22 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 23 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 24 trial
# Solving problem: Michalewicz using algorithm: BaseDE, on the: 25 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 1 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 2 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 3 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 4 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 5 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 6 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 7 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 8 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 9 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 10 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 11 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 12 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 13 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 14 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 15 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 16 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 17 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 18 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 19 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 20 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 21 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 22 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 23 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 24 trial
# Solving problem: CrossInTray using algorithm: BaseDE, on the: 25 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 1 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 2 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 3 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 4 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 5 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 6 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 7 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 8 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 9 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 10 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 11 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 12 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 13 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 14 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 15 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 16 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 17 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 18 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 19 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 20 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 21 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 22 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 23 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 24 trial
# Solving problem: Hosaki using algorithm: BaseDE, on the: 25 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 1 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 2 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 3 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 4 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 5 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 6 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 7 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 8 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 9 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 10 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 11 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 12 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 13 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 14 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 15 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 16 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 17 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 18 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 19 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 20 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 21 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 22 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 23 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 24 trial
# Solving problem: Langermann using algorithm: BaseDE, on the: 25 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 1 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 2 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 3 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 4 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 5 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 6 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 7 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 8 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 9 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 10 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 11 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 12 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 13 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 14 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 15 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 16 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 17 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 18 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 19 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 20 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 21 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 22 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 23 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 24 trial
# Solving problem: Levy5 using algorithm: BaseDE, on the: 25 trial
# Solving problem: Mishra5 using algorithm: BaseDE, on the: 1 trial
# Solving problem: Mishra5 using algorithm: BaseDE, on the: 2 trial
# Solving problem: Mishra5 using algorithm: BaseDE, on the: 3 trial
# Solving problem: Mishra5 using algorithm: BaseDE, on the: 4 trial
# Solving problem: Mishra5 using algorithm: BaseDE, on the: 5 trial
# Solving problem: Mishra5 using algorithm: BaseDE, on the: 6 trial
# Solving problem: Mishra5 using algorithm: BaseDE, on the: 7 trial
# Solving problem: Mishra5 using algorithm: BaseDE, on the: 8 trial
# ...
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 3 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 4 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 5 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 6 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 7 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 8 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 9 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 10 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 11 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 12 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 13 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 14 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 15 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 16 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 17 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 18 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 19 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 20 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 21 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 22 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 23 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 24 trial
# Solving problem: CrossInTray using algorithm: OriginalMA, on the: 25 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 1 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 2 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 3 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 4 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 5 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 6 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 7 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 8 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 9 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 10 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 11 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 12 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 13 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 14 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 15 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 16 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 17 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 18 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 19 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 20 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 21 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 22 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 23 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 24 trial
# Solving problem: Hosaki using algorithm: OriginalMA, on the: 25 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 1 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 2 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 3 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 4 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 5 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 6 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 7 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 8 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 9 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 10 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 11 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 12 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 13 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 14 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 15 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 16 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 17 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 18 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 19 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 20 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 21 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 22 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 23 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 24 trial
# Solving problem: Langermann using algorithm: OriginalMA, on the: 25 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: Levy5 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: Mishra5 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: Alpine2 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 1 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 2 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 3 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 4 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 5 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 6 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 7 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 8 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 9 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 10 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 11 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 12 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 13 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 14 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 15 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 16 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 17 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 18 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 19 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 20 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 21 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 22 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 23 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 24 trial
# Solving problem: Hansen using algorithm: OriginalMA, on the: 25 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 1 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 2 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 3 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 4 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 5 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 6 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 7 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 8 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 9 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 10 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 11 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 12 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 13 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 14 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 15 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 16 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 17 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 18 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 19 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 20 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 21 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 22 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 23 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 24 trial
# Solving problem: Himmelblau using algorithm: OriginalMA, on the: 25 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 1 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 2 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 3 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 4 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 5 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 6 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 7 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 8 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 9 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 10 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 11 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 12 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 13 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 14 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 15 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 16 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 17 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 18 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 19 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 20 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 21 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 22 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 23 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 24 trial
# Solving problem: Chichinadze using algorithm: OriginalMA, on the: 25 trial

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=[acsa], problems=Fproblems)
    multitask.execute(n_trials=25, save_path="history/evolutionary/classic", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: Ackley2 using algorithm: Model, on the: 1 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 2 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 3 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 4 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 5 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 6 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 7 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 8 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 9 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 10 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 11 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 12 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 13 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 14 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 15 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 16 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 17 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 18 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 19 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 20 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 21 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 22 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 23 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 24 trial
# Solving problem: Ackley2 using algorithm: Model, on the: 25 trial
# Solving problem: Brent using algorithm: Model, on the: 1 trial
# Solving problem: Brent using algorithm: Model, on the: 2 trial
# Solving problem: Brent using algorithm: Model, on the: 3 trial
# Solving problem: Brent using algorithm: Model, on the: 4 trial
# Solving problem: Brent using algorithm: Model, on the: 5 trial
# Solving problem: Brent using algorithm: Model, on the: 6 trial
# Solving problem: Brent using algorithm: Model, on the: 7 trial
# Solving problem: Brent using algorithm: Model, on the: 8 trial
# Solving problem: Brent using algorithm: Model, on the: 9 trial
# Solving problem: Brent using algorithm: Model, on the: 10 trial
# Solving problem: Brent using algorithm: Model, on the: 11 trial
# Solving problem: Brent using algorithm: Model, on the: 12 trial
# Solving problem: Brent using algorithm: Model, on the: 13 trial
# Solving problem: Brent using algorithm: Model, on the: 14 trial
# Solving problem: Brent using algorithm: Model, on the: 15 trial
# Solving problem: Brent using algorithm: Model, on the: 16 trial
# Solving problem: Brent using algorithm: Model, on the: 17 trial
# Solving problem: Brent using algorithm: Model, on the: 18 trial
# Solving problem: Brent using algorithm: Model, on the: 19 trial
# Solving problem: Brent using algorithm: Model, on the: 20 trial
# Solving problem: Brent using algorithm: Model, on the: 21 trial
# Solving problem: Brent using algorithm: Model, on the: 22 trial
# Solving problem: Brent using algorithm: Model, on the: 23 trial
# Solving problem: Brent using algorithm: Model, on the: 24 trial
# Solving problem: Brent using algorithm: Model, on the: 25 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 1 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 2 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 3 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 4 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 5 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 6 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 7 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 8 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 9 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 10 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 11 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 12 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 13 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 14 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 15 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 16 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 17 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 18 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 19 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 20 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 21 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 22 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 23 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 24 trial
# Solving problem: ChungReynolds using algorithm: Model, on the: 25 trial
# Solving problem: Cigar using algorithm: Model, on the: 1 trial
# Solving problem: Cigar using algorithm: Model, on the: 2 trial
# Solving problem: Cigar using algorithm: Model, on the: 3 trial
# Solving problem: Cigar using algorithm: Model, on the: 4 trial
# Solving problem: Cigar using algorithm: Model, on the: 5 trial
# Solving problem: Cigar using algorithm: Model, on the: 6 trial
# Solving problem: Cigar using algorithm: Model, on the: 7 trial
# Solving problem: Cigar using algorithm: Model, on the: 8 trial
# Solving problem: Cigar using algorithm: Model, on the: 9 trial
# Solving problem: Cigar using algorithm: Model, on the: 10 trial
# Solving problem: Cigar using algorithm: Model, on the: 11 trial
# Solving problem: Cigar using algorithm: Model, on the: 12 trial
# Solving problem: Cigar using algorithm: Model, on the: 13 trial
# Solving problem: Cigar using algorithm: Model, on the: 14 trial
# Solving problem: Cigar using algorithm: Model, on the: 15 trial
# Solving problem: Cigar using algorithm: Model, on the: 16 trial
# Solving problem: Cigar using algorithm: Model, on the: 17 trial
# Solving problem: Cigar using algorithm: Model, on the: 18 trial
# Solving problem: Cigar using algorithm: Model, on the: 19 trial
# Solving problem: Cigar using algorithm: Model, on the: 20 trial
# Solving problem: Cigar using algorithm: Model, on the: 21 trial
# Solving problem: Cigar using algorithm: Model, on the: 22 trial
# Solving problem: Cigar using algorithm: Model, on the: 23 trial
# Solving problem: Cigar using algorithm: Model, on the: 24 trial
# Solving problem: Cigar using algorithm: Model, on the: 25 trial
# Solving problem: Matyas using algorithm: Model, on the: 1 trial
# Solving problem: Matyas using algorithm: Model, on the: 2 trial
# Solving problem: Matyas using algorithm: Model, on the: 3 trial
# Solving problem: Matyas using algorithm: Model, on the: 4 trial
# Solving problem: Matyas using algorithm: Model, on the: 5 trial
# Solving problem: Matyas using algorithm: Model, on the: 6 trial
# Solving problem: Matyas using algorithm: Model, on the: 7 trial
# Solving problem: Matyas using algorithm: Model, on the: 8 trial
# Solving problem: Matyas using algorithm: Model, on the: 9 trial
# Solving problem: Matyas using algorithm: Model, on the: 10 trial
# Solving problem: Matyas using algorithm: Model, on the: 11 trial
# Solving problem: Matyas using algorithm: Model, on the: 12 trial
# Solving problem: Matyas using algorithm: Model, on the: 13 trial
# Solving problem: Matyas using algorithm: Model, on the: 14 trial
# Solving problem: Matyas using algorithm: Model, on the: 15 trial
# Solving problem: Matyas using algorithm: Model, on the: 16 trial
# Solving problem: Matyas using algorithm: Model, on the: 17 trial
# Solving problem: Matyas using algorithm: Model, on the: 18 trial
# Solving problem: Matyas using algorithm: Model, on the: 19 trial
# Solving problem: Matyas using algorithm: Model, on the: 20 trial
# Solving problem: Matyas using algorithm: Model, on the: 21 trial
# Solving problem: Matyas using algorithm: Model, on the: 22 trial
# Solving problem: Matyas using algorithm: Model, on the: 23 trial
# Solving problem: Matyas using algorithm: Model, on the: 24 trial
# Solving problem: Matyas using algorithm: Model, on the: 25 trial
# Solving problem: Leon using algorithm: Model, on the: 1 trial
# Solving problem: Leon using algorithm: Model, on the: 2 trial
# Solving problem: Leon using algorithm: Model, on the: 3 trial
# Solving problem: Leon using algorithm: Model, on the: 4 trial
# Solving problem: Leon using algorithm: Model, on the: 5 trial
# Solving problem: Leon using algorithm: Model, on the: 6 trial
# Solving problem: Leon using algorithm: Model, on the: 7 trial
# Solving problem: Leon using algorithm: Model, on the: 8 trial
# Solving problem: Leon using algorithm: Model, on the: 9 trial
# Solving problem: Leon using algorithm: Model, on the: 10 trial
# Solving problem: Leon using algorithm: Model, on the: 11 trial
# Solving problem: Leon using algorithm: Model, on the: 12 trial
# Solving problem: Leon using algorithm: Model, on the: 13 trial
# Solving problem: Leon using algorithm: Model, on the: 14 trial
# Solving problem: Leon using algorithm: Model, on the: 15 trial
# Solving problem: Leon using algorithm: Model, on the: 16 trial
# Solving problem: Leon using algorithm: Model, on the: 17 trial
# Solving problem: Leon using algorithm: Model, on the: 18 trial
# Solving problem: Leon using algorithm: Model, on the: 19 trial
# Solving problem: Leon using algorithm: Model, on the: 20 trial
# Solving problem: Leon using algorithm: Model, on the: 21 trial
# Solving problem: Leon using algorithm: Model, on the: 22 trial
# Solving problem: Leon using algorithm: Model, on the: 23 trial
# Solving problem: Leon using algorithm: Model, on the: 24 trial
# Solving problem: Leon using algorithm: Model, on the: 25 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 1 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 2 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 3 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 4 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 5 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 6 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 7 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 8 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 9 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 10 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 11 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 12 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 13 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 14 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 15 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 16 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 17 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 18 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 19 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 20 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 21 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 22 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 23 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 24 trial
# Solving problem: Michalewicz using algorithm: Model, on the: 25 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 1 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 2 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 3 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 4 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 5 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 6 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 7 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 8 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 9 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 10 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 11 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 12 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 13 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 14 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 15 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 16 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 17 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 18 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 19 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 20 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 21 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 22 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 23 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 24 trial
# Solving problem: CrossInTray using algorithm: Model, on the: 25 trial
# Solving problem: Hosaki using algorithm: Model, on the: 1 trial
# Solving problem: Hosaki using algorithm: Model, on the: 2 trial
# Solving problem: Hosaki using algorithm: Model, on the: 3 trial
# Solving problem: Hosaki using algorithm: Model, on the: 4 trial
# Solving problem: Hosaki using algorithm: Model, on the: 5 trial
# Solving problem: Hosaki using algorithm: Model, on the: 6 trial
# Solving problem: Hosaki using algorithm: Model, on the: 7 trial
# Solving problem: Hosaki using algorithm: Model, on the: 8 trial
# Solving problem: Hosaki using algorithm: Model, on the: 9 trial
# Solving problem: Hosaki using algorithm: Model, on the: 10 trial
# Solving problem: Hosaki using algorithm: Model, on the: 11 trial
# Solving problem: Hosaki using algorithm: Model, on the: 12 trial
# Solving problem: Hosaki using algorithm: Model, on the: 13 trial
# Solving problem: Hosaki using algorithm: Model, on the: 14 trial
# Solving problem: Hosaki using algorithm: Model, on the: 15 trial
# Solving problem: Hosaki using algorithm: Model, on the: 16 trial
# Solving problem: Hosaki using algorithm: Model, on the: 17 trial
# Solving problem: Hosaki using algorithm: Model, on the: 18 trial
# Solving problem: Hosaki using algorithm: Model, on the: 19 trial
# Solving problem: Hosaki using algorithm: Model, on the: 20 trial
# Solving problem: Hosaki using algorithm: Model, on the: 21 trial
# Solving problem: Hosaki using algorithm: Model, on the: 22 trial
# Solving problem: Hosaki using algorithm: Model, on the: 23 trial
# Solving problem: Hosaki using algorithm: Model, on the: 24 trial
# Solving problem: Hosaki using algorithm: Model, on the: 25 trial
# Solving problem: Langermann using algorithm: Model, on the: 1 trial
# Solving problem: Langermann using algorithm: Model, on the: 2 trial
# Solving problem: Langermann using algorithm: Model, on the: 3 trial
# Solving problem: Langermann using algorithm: Model, on the: 4 trial
# Solving problem: Langermann using algorithm: Model, on the: 5 trial
# Solving problem: Langermann using algorithm: Model, on the: 6 trial
# Solving problem: Langermann using algorithm: Model, on the: 7 trial
# Solving problem: Langermann using algorithm: Model, on the: 8 trial
# Solving problem: Langermann using algorithm: Model, on the: 9 trial
# Solving problem: Langermann using algorithm: Model, on the: 10 trial
# Solving problem: Langermann using algorithm: Model, on the: 11 trial
# Solving problem: Langermann using algorithm: Model, on the: 12 trial
# Solving problem: Langermann using algorithm: Model, on the: 13 trial
# Solving problem: Langermann using algorithm: Model, on the: 14 trial
# Solving problem: Langermann using algorithm: Model, on the: 15 trial
# Solving problem: Langermann using algorithm: Model, on the: 16 trial
# Solving problem: Langermann using algorithm: Model, on the: 17 trial
# Solving problem: Langermann using algorithm: Model, on the: 18 trial
# Solving problem: Langermann using algorithm: Model, on the: 19 trial
# Solving problem: Langermann using algorithm: Model, on the: 20 trial
# Solving problem: Langermann using algorithm: Model, on the: 21 trial
# Solving problem: Langermann using algorithm: Model, on the: 22 trial
# Solving problem: Langermann using algorithm: Model, on the: 23 trial
# Solving problem: Langermann using algorithm: Model, on the: 24 trial
# Solving problem: Langermann using algorithm: Model, on the: 25 trial
# Solving problem: Levy5 using algorithm: Model, on the: 1 trial
# Solving problem: Levy5 using algorithm: Model, on the: 2 trial
# Solving problem: Levy5 using algorithm: Model, on the: 3 trial
# Solving problem: Levy5 using algorithm: Model, on the: 4 trial
# Solving problem: Levy5 using algorithm: Model, on the: 5 trial
# Solving problem: Levy5 using algorithm: Model, on the: 6 trial
# Solving problem: Levy5 using algorithm: Model, on the: 7 trial
# Solving problem: Levy5 using algorithm: Model, on the: 8 trial
# Solving problem: Levy5 using algorithm: Model, on the: 9 trial
# Solving problem: Levy5 using algorithm: Model, on the: 10 trial
# Solving problem: Levy5 using algorithm: Model, on the: 11 trial
# Solving problem: Levy5 using algorithm: Model, on the: 12 trial
# Solving problem: Levy5 using algorithm: Model, on the: 13 trial
# Solving problem: Levy5 using algorithm: Model, on the: 14 trial
# Solving problem: Levy5 using algorithm: Model, on the: 15 trial
# Solving problem: Levy5 using algorithm: Model, on the: 16 trial
# Solving problem: Levy5 using algorithm: Model, on the: 17 trial
# Solving problem: Levy5 using algorithm: Model, on the: 18 trial
# Solving problem: Levy5 using algorithm: Model, on the: 19 trial
# Solving problem: Levy5 using algorithm: Model, on the: 20 trial
# Solving problem: Levy5 using algorithm: Model, on the: 21 trial
# Solving problem: Levy5 using algorithm: Model, on the: 22 trial
# Solving problem: Levy5 using algorithm: Model, on the: 23 trial
# Solving problem: Levy5 using algorithm: Model, on the: 24 trial
# Solving problem: Levy5 using algorithm: Model, on the: 25 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 1 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 2 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 3 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 4 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 5 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 6 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 7 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 8 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 9 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 10 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 11 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 12 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 13 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 14 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 15 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 16 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 17 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 18 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 19 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 20 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 21 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 22 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 23 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 24 trial
# Solving problem: Mishra5 using algorithm: Model, on the: 25 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 1 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 2 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 3 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 4 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 5 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 6 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 7 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 8 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 9 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 10 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 11 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 12 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 13 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 14 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 15 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 16 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 17 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 18 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 19 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 20 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 21 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 22 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 23 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 24 trial
# Solving problem: Alpine2 using algorithm: Model, on the: 25 trial
# Solving problem: Hansen using algorithm: Model, on the: 1 trial
# Solving problem: Hansen using algorithm: Model, on the: 2 trial
# Solving problem: Hansen using algorithm: Model, on the: 3 trial
# Solving problem: Hansen using algorithm: Model, on the: 4 trial
# Solving problem: Hansen using algorithm: Model, on the: 5 trial
# Solving problem: Hansen using algorithm: Model, on the: 6 trial
# Solving problem: Hansen using algorithm: Model, on the: 7 trial
# Solving problem: Hansen using algorithm: Model, on the: 8 trial
# Solving problem: Hansen using algorithm: Model, on the: 9 trial
# Solving problem: Hansen using algorithm: Model, on the: 10 trial
# Solving problem: Hansen using algorithm: Model, on the: 11 trial
# Solving problem: Hansen using algorithm: Model, on the: 12 trial
# Solving problem: Hansen using algorithm: Model, on the: 13 trial
# Solving problem: Hansen using algorithm: Model, on the: 14 trial
# Solving problem: Hansen using algorithm: Model, on the: 15 trial
# Solving problem: Hansen using algorithm: Model, on the: 16 trial
# Solving problem: Hansen using algorithm: Model, on the: 17 trial
# Solving problem: Hansen using algorithm: Model, on the: 18 trial
# Solving problem: Hansen using algorithm: Model, on the: 19 trial
# Solving problem: Hansen using algorithm: Model, on the: 20 trial
# Solving problem: Hansen using algorithm: Model, on the: 21 trial
# Solving problem: Hansen using algorithm: Model, on the: 22 trial
# Solving problem: Hansen using algorithm: Model, on the: 23 trial
# Solving problem: Hansen using algorithm: Model, on the: 24 trial
# Solving problem: Hansen using algorithm: Model, on the: 25 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 1 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 2 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 3 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 4 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 5 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 6 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 7 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 8 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 9 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 10 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 11 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 12 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 13 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 14 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 15 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 16 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 17 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 18 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 19 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 20 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 21 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 22 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 23 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 24 trial
# Solving problem: Himmelblau using algorithm: Model, on the: 25 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 1 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 2 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 3 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 4 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 5 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 6 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 7 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 8 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 9 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 10 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 11 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 12 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 13 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 14 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 15 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 16 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 17 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 18 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 19 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 20 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 21 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 22 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 23 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 24 trial
# Solving problem: Chichinadze using algorithm: Model, on the: 25 trial

# %% [markdown]
# #### CEC22 TEST FUNCTION

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=list_models, problems=Cproblems)
    multitask.execute(n_trials=25, save_path="history/evolutionary/cec22", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F12022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F22022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F32022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F42022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F52022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F62022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F72022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F82022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F92022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F102022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F112022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 1 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 2 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 3 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 4 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 5 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 6 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 7 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 8 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 9 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 10 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 11 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 12 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 13 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 14 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 15 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 16 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 17 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 18 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 19 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 20 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 21 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 22 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 23 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 24 trial
# Solving problem: F122022 using algorithm: OriginalCRO, on the: 25 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F12022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F22022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F32022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F42022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F52022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F62022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F72022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F82022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F92022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F102022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F112022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 1 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 2 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 3 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 4 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 5 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 6 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 7 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 8 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 9 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 10 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 11 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 12 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 13 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 14 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 15 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 16 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 17 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 18 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 19 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 20 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 21 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 22 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 23 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 24 trial
# Solving problem: F122022 using algorithm: BaseDE, on the: 25 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 1 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 2 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 3 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 4 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 5 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 6 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 7 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 8 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 9 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 10 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 11 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 12 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 13 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 14 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 15 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 16 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 17 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 18 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 19 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 20 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 21 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 22 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 23 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 24 trial
# Solving problem: F12022 using algorithm: OriginalES, on the: 25 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 1 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 2 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 3 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 4 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 5 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 6 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 7 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 8 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 9 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 10 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 11 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 12 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 13 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 14 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 15 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 16 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 17 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 18 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 19 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 20 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 21 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 22 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 23 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 24 trial
# Solving problem: F22022 using algorithm: OriginalES, on the: 25 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 1 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 2 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 3 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 4 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 5 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 6 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 7 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 8 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 9 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 10 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 11 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 12 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 13 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 14 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 15 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 16 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 17 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 18 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 19 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 20 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 21 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 22 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 23 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 24 trial
# Solving problem: F32022 using algorithm: OriginalES, on the: 25 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 1 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 2 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 3 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 4 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 5 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 6 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 7 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 8 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 9 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 10 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 11 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 12 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 13 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 14 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 15 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 16 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 17 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 18 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 19 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 20 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 21 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 22 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 23 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 24 trial
# Solving problem: F42022 using algorithm: OriginalES, on the: 25 trial
# ...
# Solving problem: F32022 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: F32022 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: F32022 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: F42022 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: F52022 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: F62022 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: F72022 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: F82022 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: F92022 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: F102022 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: F112022 using algorithm: OriginalMA, on the: 25 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 1 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 2 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 3 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 4 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 5 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 6 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 7 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 8 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 9 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 10 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 11 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 12 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 13 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 14 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 15 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 16 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 17 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 18 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 19 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 20 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 21 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 22 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 23 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 24 trial
# Solving problem: F122022 using algorithm: OriginalMA, on the: 25 trial

# %%
if __name__ == "__main__":
    multitask = Multitask(algorithms=[acsa], problems=Cproblems)
    multitask.execute(n_trials=25, save_path="history/evolutionary/cec22", save_as="csv", save_convergence=True, verbose=True)
# Out:
# Solving problem: F12022 using algorithm: Model, on the: 1 trial
# Solving problem: F12022 using algorithm: Model, on the: 2 trial
# Solving problem: F12022 using algorithm: Model, on the: 3 trial
# Solving problem: F12022 using algorithm: Model, on the: 4 trial
# Solving problem: F12022 using algorithm: Model, on the: 5 trial
# Solving problem: F12022 using algorithm: Model, on the: 6 trial
# Solving problem: F12022 using algorithm: Model, on the: 7 trial
# Solving problem: F12022 using algorithm: Model, on the: 8 trial
# Solving problem: F12022 using algorithm: Model, on the: 9 trial
# Solving problem: F12022 using algorithm: Model, on the: 10 trial
# Solving problem: F12022 using algorithm: Model, on the: 11 trial
# Solving problem: F12022 using algorithm: Model, on the: 12 trial
# Solving problem: F12022 using algorithm: Model, on the: 13 trial
# Solving problem: F12022 using algorithm: Model, on the: 14 trial
# Solving problem: F12022 using algorithm: Model, on the: 15 trial
# Solving problem: F12022 using algorithm: Model, on the: 16 trial
# Solving problem: F12022 using algorithm: Model, on the: 17 trial
# Solving problem: F12022 using algorithm: Model, on the: 18 trial
# Solving problem: F12022 using algorithm: Model, on the: 19 trial
# Solving problem: F12022 using algorithm: Model, on the: 20 trial
# Solving problem: F12022 using algorithm: Model, on the: 21 trial
# Solving problem: F12022 using algorithm: Model, on the: 22 trial
# Solving problem: F12022 using algorithm: Model, on the: 23 trial
# Solving problem: F12022 using algorithm: Model, on the: 24 trial
# Solving problem: F12022 using algorithm: Model, on the: 25 trial
# Solving problem: F22022 using algorithm: Model, on the: 1 trial
# Solving problem: F22022 using algorithm: Model, on the: 2 trial
# Solving problem: F22022 using algorithm: Model, on the: 3 trial
# Solving problem: F22022 using algorithm: Model, on the: 4 trial
# Solving problem: F22022 using algorithm: Model, on the: 5 trial
# Solving problem: F22022 using algorithm: Model, on the: 6 trial
# Solving problem: F22022 using algorithm: Model, on the: 7 trial
# Solving problem: F22022 using algorithm: Model, on the: 8 trial
# Solving problem: F22022 using algorithm: Model, on the: 9 trial
# Solving problem: F22022 using algorithm: Model, on the: 10 trial
# Solving problem: F22022 using algorithm: Model, on the: 11 trial
# Solving problem: F22022 using algorithm: Model, on the: 12 trial
# Solving problem: F22022 using algorithm: Model, on the: 13 trial
# Solving problem: F22022 using algorithm: Model, on the: 14 trial
# Solving problem: F22022 using algorithm: Model, on the: 15 trial
# Solving problem: F22022 using algorithm: Model, on the: 16 trial
# Solving problem: F22022 using algorithm: Model, on the: 17 trial
# Solving problem: F22022 using algorithm: Model, on the: 18 trial
# Solving problem: F22022 using algorithm: Model, on the: 19 trial
# Solving problem: F22022 using algorithm: Model, on the: 20 trial
# Solving problem: F22022 using algorithm: Model, on the: 21 trial
# Solving problem: F22022 using algorithm: Model, on the: 22 trial
# Solving problem: F22022 using algorithm: Model, on the: 23 trial
# Solving problem: F22022 using algorithm: Model, on the: 24 trial
# Solving problem: F22022 using algorithm: Model, on the: 25 trial
# Solving problem: F32022 using algorithm: Model, on the: 1 trial
# Solving problem: F32022 using algorithm: Model, on the: 2 trial
# Solving problem: F32022 using algorithm: Model, on the: 3 trial
# Solving problem: F32022 using algorithm: Model, on the: 4 trial
# Solving problem: F32022 using algorithm: Model, on the: 5 trial
# Solving problem: F32022 using algorithm: Model, on the: 6 trial
# Solving problem: F32022 using algorithm: Model, on the: 7 trial
# Solving problem: F32022 using algorithm: Model, on the: 8 trial
# Solving problem: F32022 using algorithm: Model, on the: 9 trial
# Solving problem: F32022 using algorithm: Model, on the: 10 trial
# Solving problem: F32022 using algorithm: Model, on the: 11 trial
# Solving problem: F32022 using algorithm: Model, on the: 12 trial
# Solving problem: F32022 using algorithm: Model, on the: 13 trial
# Solving problem: F32022 using algorithm: Model, on the: 14 trial
# Solving problem: F32022 using algorithm: Model, on the: 15 trial
# Solving problem: F32022 using algorithm: Model, on the: 16 trial
# Solving problem: F32022 using algorithm: Model, on the: 17 trial
# Solving problem: F32022 using algorithm: Model, on the: 18 trial
# Solving problem: F32022 using algorithm: Model, on the: 19 trial
# Solving problem: F32022 using algorithm: Model, on the: 20 trial
# Solving problem: F32022 using algorithm: Model, on the: 21 trial
# Solving problem: F32022 using algorithm: Model, on the: 22 trial
# Solving problem: F32022 using algorithm: Model, on the: 23 trial
# Solving problem: F32022 using algorithm: Model, on the: 24 trial
# Solving problem: F32022 using algorithm: Model, on the: 25 trial
# Solving problem: F42022 using algorithm: Model, on the: 1 trial
# Solving problem: F42022 using algorithm: Model, on the: 2 trial
# Solving problem: F42022 using algorithm: Model, on the: 3 trial
# Solving problem: F42022 using algorithm: Model, on the: 4 trial
# Solving problem: F42022 using algorithm: Model, on the: 5 trial
# Solving problem: F42022 using algorithm: Model, on the: 6 trial
# Solving problem: F42022 using algorithm: Model, on the: 7 trial
# Solving problem: F42022 using algorithm: Model, on the: 8 trial
# Solving problem: F42022 using algorithm: Model, on the: 9 trial
# Solving problem: F42022 using algorithm: Model, on the: 10 trial
# Solving problem: F42022 using algorithm: Model, on the: 11 trial
# Solving problem: F42022 using algorithm: Model, on the: 12 trial
# Solving problem: F42022 using algorithm: Model, on the: 13 trial
# Solving problem: F42022 using algorithm: Model, on the: 14 trial
# Solving problem: F42022 using algorithm: Model, on the: 15 trial
# Solving problem: F42022 using algorithm: Model, on the: 16 trial
# Solving problem: F42022 using algorithm: Model, on the: 17 trial
# Solving problem: F42022 using algorithm: Model, on the: 18 trial
# Solving problem: F42022 using algorithm: Model, on the: 19 trial
# Solving problem: F42022 using algorithm: Model, on the: 20 trial
# Solving problem: F42022 using algorithm: Model, on the: 21 trial
# Solving problem: F42022 using algorithm: Model, on the: 22 trial
# Solving problem: F42022 using algorithm: Model, on the: 23 trial
# Solving problem: F42022 using algorithm: Model, on the: 24 trial
# Solving problem: F42022 using algorithm: Model, on the: 25 trial
# Solving problem: F52022 using algorithm: Model, on the: 1 trial
# Solving problem: F52022 using algorithm: Model, on the: 2 trial
# Solving problem: F52022 using algorithm: Model, on the: 3 trial
# Solving problem: F52022 using algorithm: Model, on the: 4 trial
# Solving problem: F52022 using algorithm: Model, on the: 5 trial
# Solving problem: F52022 using algorithm: Model, on the: 6 trial
# Solving problem: F52022 using algorithm: Model, on the: 7 trial
# Solving problem: F52022 using algorithm: Model, on the: 8 trial
# Solving problem: F52022 using algorithm: Model, on the: 9 trial
# Solving problem: F52022 using algorithm: Model, on the: 10 trial
# Solving problem: F52022 using algorithm: Model, on the: 11 trial
# Solving problem: F52022 using algorithm: Model, on the: 12 trial
# Solving problem: F52022 using algorithm: Model, on the: 13 trial
# Solving problem: F52022 using algorithm: Model, on the: 14 trial
# Solving problem: F52022 using algorithm: Model, on the: 15 trial
# Solving problem: F52022 using algorithm: Model, on the: 16 trial
# Solving problem: F52022 using algorithm: Model, on the: 17 trial
# Solving problem: F52022 using algorithm: Model, on the: 18 trial
# Solving problem: F52022 using algorithm: Model, on the: 19 trial
# Solving problem: F52022 using algorithm: Model, on the: 20 trial
# Solving problem: F52022 using algorithm: Model, on the: 21 trial
# Solving problem: F52022 using algorithm: Model, on the: 22 trial
# Solving problem: F52022 using algorithm: Model, on the: 23 trial
# Solving problem: F52022 using algorithm: Model, on the: 24 trial
# Solving problem: F52022 using algorithm: Model, on the: 25 trial
# Solving problem: F62022 using algorithm: Model, on the: 1 trial
# Solving problem: F62022 using algorithm: Model, on the: 2 trial
# Solving problem: F62022 using algorithm: Model, on the: 3 trial
# Solving problem: F62022 using algorithm: Model, on the: 4 trial
# Solving problem: F62022 using algorithm: Model, on the: 5 trial
# Solving problem: F62022 using algorithm: Model, on the: 6 trial
# Solving problem: F62022 using algorithm: Model, on the: 7 trial
# Solving problem: F62022 using algorithm: Model, on the: 8 trial
# Solving problem: F62022 using algorithm: Model, on the: 9 trial
# Solving problem: F62022 using algorithm: Model, on the: 10 trial
# Solving problem: F62022 using algorithm: Model, on the: 11 trial
# Solving problem: F62022 using algorithm: Model, on the: 12 trial
# Solving problem: F62022 using algorithm: Model, on the: 13 trial
# Solving problem: F62022 using algorithm: Model, on the: 14 trial
# Solving problem: F62022 using algorithm: Model, on the: 15 trial
# Solving problem: F62022 using algorithm: Model, on the: 16 trial
# Solving problem: F62022 using algorithm: Model, on the: 17 trial
# Solving problem: F62022 using algorithm: Model, on the: 18 trial
# Solving problem: F62022 using algorithm: Model, on the: 19 trial
# Solving problem: F62022 using algorithm: Model, on the: 20 trial
# Solving problem: F62022 using algorithm: Model, on the: 21 trial
# Solving problem: F62022 using algorithm: Model, on the: 22 trial
# Solving problem: F62022 using algorithm: Model, on the: 23 trial
# Solving problem: F62022 using algorithm: Model, on the: 24 trial
# Solving problem: F62022 using algorithm: Model, on the: 25 trial
# Solving problem: F72022 using algorithm: Model, on the: 1 trial
# Solving problem: F72022 using algorithm: Model, on the: 2 trial
# Solving problem: F72022 using algorithm: Model, on the: 3 trial
# Solving problem: F72022 using algorithm: Model, on the: 4 trial
# Solving problem: F72022 using algorithm: Model, on the: 5 trial
# Solving problem: F72022 using algorithm: Model, on the: 6 trial
# Solving problem: F72022 using algorithm: Model, on the: 7 trial
# Solving problem: F72022 using algorithm: Model, on the: 8 trial
# Solving problem: F72022 using algorithm: Model, on the: 9 trial
# Solving problem: F72022 using algorithm: Model, on the: 10 trial
# Solving problem: F72022 using algorithm: Model, on the: 11 trial
# Solving problem: F72022 using algorithm: Model, on the: 12 trial
# Solving problem: F72022 using algorithm: Model, on the: 13 trial
# Solving problem: F72022 using algorithm: Model, on the: 14 trial
# Solving problem: F72022 using algorithm: Model, on the: 15 trial
# Solving problem: F72022 using algorithm: Model, on the: 16 trial
# Solving problem: F72022 using algorithm: Model, on the: 17 trial
# Solving problem: F72022 using algorithm: Model, on the: 18 trial
# Solving problem: F72022 using algorithm: Model, on the: 19 trial
# Solving problem: F72022 using algorithm: Model, on the: 20 trial
# Solving problem: F72022 using algorithm: Model, on the: 21 trial
# Solving problem: F72022 using algorithm: Model, on the: 22 trial
# Solving problem: F72022 using algorithm: Model, on the: 23 trial
# Solving problem: F72022 using algorithm: Model, on the: 24 trial
# Solving problem: F72022 using algorithm: Model, on the: 25 trial
# Solving problem: F82022 using algorithm: Model, on the: 1 trial
# Solving problem: F82022 using algorithm: Model, on the: 2 trial
# Solving problem: F82022 using algorithm: Model, on the: 3 trial
# Solving problem: F82022 using algorithm: Model, on the: 4 trial
# Solving problem: F82022 using algorithm: Model, on the: 5 trial
# Solving problem: F82022 using algorithm: Model, on the: 6 trial
# Solving problem: F82022 using algorithm: Model, on the: 7 trial
# Solving problem: F82022 using algorithm: Model, on the: 8 trial
# Solving problem: F82022 using algorithm: Model, on the: 9 trial
# Solving problem: F82022 using algorithm: Model, on the: 10 trial
# Solving problem: F82022 using algorithm: Model, on the: 11 trial
# Solving problem: F82022 using algorithm: Model, on the: 12 trial
# Solving problem: F82022 using algorithm: Model, on the: 13 trial
# Solving problem: F82022 using algorithm: Model, on the: 14 trial
# Solving problem: F82022 using algorithm: Model, on the: 15 trial
# Solving problem: F82022 using algorithm: Model, on the: 16 trial
# Solving problem: F82022 using algorithm: Model, on the: 17 trial
# Solving problem: F82022 using algorithm: Model, on the: 18 trial
# Solving problem: F82022 using algorithm: Model, on the: 19 trial
# Solving problem: F82022 using algorithm: Model, on the: 20 trial
# Solving problem: F82022 using algorithm: Model, on the: 21 trial
# Solving problem: F82022 using algorithm: Model, on the: 22 trial
# Solving problem: F82022 using algorithm: Model, on the: 23 trial
# Solving problem: F82022 using algorithm: Model, on the: 24 trial
# Solving problem: F82022 using algorithm: Model, on the: 25 trial
# Solving problem: F92022 using algorithm: Model, on the: 1 trial
# Solving problem: F92022 using algorithm: Model, on the: 2 trial
# Solving problem: F92022 using algorithm: Model, on the: 3 trial
# Solving problem: F92022 using algorithm: Model, on the: 4 trial
# Solving problem: F92022 using algorithm: Model, on the: 5 trial
# Solving problem: F92022 using algorithm: Model, on the: 6 trial
# Solving problem: F92022 using algorithm: Model, on the: 7 trial
# Solving problem: F92022 using algorithm: Model, on the: 8 trial
# Solving problem: F92022 using algorithm: Model, on the: 9 trial
# Solving problem: F92022 using algorithm: Model, on the: 10 trial
# Solving problem: F92022 using algorithm: Model, on the: 11 trial
# Solving problem: F92022 using algorithm: Model, on the: 12 trial
# Solving problem: F92022 using algorithm: Model, on the: 13 trial
# Solving problem: F92022 using algorithm: Model, on the: 14 trial
# Solving problem: F92022 using algorithm: Model, on the: 15 trial
# Solving problem: F92022 using algorithm: Model, on the: 16 trial
# Solving problem: F92022 using algorithm: Model, on the: 17 trial
# Solving problem: F92022 using algorithm: Model, on the: 18 trial
# Solving problem: F92022 using algorithm: Model, on the: 19 trial
# Solving problem: F92022 using algorithm: Model, on the: 20 trial
# Solving problem: F92022 using algorithm: Model, on the: 21 trial
# Solving problem: F92022 using algorithm: Model, on the: 22 trial
# Solving problem: F92022 using algorithm: Model, on the: 23 trial
# Solving problem: F92022 using algorithm: Model, on the: 24 trial
# Solving problem: F92022 using algorithm: Model, on the: 25 trial
# Solving problem: F102022 using algorithm: Model, on the: 1 trial
# Solving problem: F102022 using algorithm: Model, on the: 2 trial
# Solving problem: F102022 using algorithm: Model, on the: 3 trial
# Solving problem: F102022 using algorithm: Model, on the: 4 trial
# Solving problem: F102022 using algorithm: Model, on the: 5 trial
# Solving problem: F102022 using algorithm: Model, on the: 6 trial
# Solving problem: F102022 using algorithm: Model, on the: 7 trial
# Solving problem: F102022 using algorithm: Model, on the: 8 trial
# Solving problem: F102022 using algorithm: Model, on the: 9 trial
# Solving problem: F102022 using algorithm: Model, on the: 10 trial
# Solving problem: F102022 using algorithm: Model, on the: 11 trial
# Solving problem: F102022 using algorithm: Model, on the: 12 trial
# Solving problem: F102022 using algorithm: Model, on the: 13 trial
# Solving problem: F102022 using algorithm: Model, on the: 14 trial
# Solving problem: F102022 using algorithm: Model, on the: 15 trial
# Solving problem: F102022 using algorithm: Model, on the: 16 trial
# Solving problem: F102022 using algorithm: Model, on the: 17 trial
# Solving problem: F102022 using algorithm: Model, on the: 18 trial
# Solving problem: F102022 using algorithm: Model, on the: 19 trial
# Solving problem: F102022 using algorithm: Model, on the: 20 trial
# Solving problem: F102022 using algorithm: Model, on the: 21 trial
# Solving problem: F102022 using algorithm: Model, on the: 22 trial
# Solving problem: F102022 using algorithm: Model, on the: 23 trial
# Solving problem: F102022 using algorithm: Model, on the: 24 trial
# Solving problem: F102022 using algorithm: Model, on the: 25 trial
# Solving problem: F112022 using algorithm: Model, on the: 1 trial
# Solving problem: F112022 using algorithm: Model, on the: 2 trial
# Solving problem: F112022 using algorithm: Model, on the: 3 trial
# Solving problem: F112022 using algorithm: Model, on the: 4 trial
# Solving problem: F112022 using algorithm: Model, on the: 5 trial
# Solving problem: F112022 using algorithm: Model, on the: 6 trial
# Solving problem: F112022 using algorithm: Model, on the: 7 trial
# Solving problem: F112022 using algorithm: Model, on the: 8 trial
# Solving problem: F112022 using algorithm: Model, on the: 9 trial
# Solving problem: F112022 using algorithm: Model, on the: 10 trial
# Solving problem: F112022 using algorithm: Model, on the: 11 trial
# Solving problem: F112022 using algorithm: Model, on the: 12 trial
# Solving problem: F112022 using algorithm: Model, on the: 13 trial
# Solving problem: F112022 using algorithm: Model, on the: 14 trial
# Solving problem: F112022 using algorithm: Model, on the: 15 trial
# Solving problem: F112022 using algorithm: Model, on the: 16 trial
# Solving problem: F112022 using algorithm: Model, on the: 17 trial
# Solving problem: F112022 using algorithm: Model, on the: 18 trial
# Solving problem: F112022 using algorithm: Model, on the: 19 trial
# Solving problem: F112022 using algorithm: Model, on the: 20 trial
# Solving problem: F112022 using algorithm: Model, on the: 21 trial
# Solving problem: F112022 using algorithm: Model, on the: 22 trial
# Solving problem: F112022 using algorithm: Model, on the: 23 trial
# Solving problem: F112022 using algorithm: Model, on the: 24 trial
# Solving problem: F112022 using algorithm: Model, on the: 25 trial
# Solving problem: F122022 using algorithm: Model, on the: 1 trial
# Solving problem: F122022 using algorithm: Model, on the: 2 trial
# Solving problem: F122022 using algorithm: Model, on the: 3 trial
# Solving problem: F122022 using algorithm: Model, on the: 4 trial
# Solving problem: F122022 using algorithm: Model, on the: 5 trial
# Solving problem: F122022 using algorithm: Model, on the: 6 trial
# Solving problem: F122022 using algorithm: Model, on the: 7 trial
# Solving problem: F122022 using algorithm: Model, on the: 8 trial
# Solving problem: F122022 using algorithm: Model, on the: 9 trial
# Solving problem: F122022 using algorithm: Model, on the: 10 trial
# Solving problem: F122022 using algorithm: Model, on the: 11 trial
# Solving problem: F122022 using algorithm: Model, on the: 12 trial
# Solving problem: F122022 using algorithm: Model, on the: 13 trial
# Solving problem: F122022 using algorithm: Model, on the: 14 trial
# Solving problem: F122022 using algorithm: Model, on the: 15 trial
# Solving problem: F122022 using algorithm: Model, on the: 16 trial
# Solving problem: F122022 using algorithm: Model, on the: 17 trial
# Solving problem: F122022 using algorithm: Model, on the: 18 trial
# Solving problem: F122022 using algorithm: Model, on the: 19 trial
# Solving problem: F122022 using algorithm: Model, on the: 20 trial
# Solving problem: F122022 using algorithm: Model, on the: 21 trial
# Solving problem: F122022 using algorithm: Model, on the: 22 trial
# Solving problem: F122022 using algorithm: Model, on the: 23 trial
# Solving problem: F122022 using algorithm: Model, on the: 24 trial
# Solving problem: F122022 using algorithm: Model, on the: 25 trial
